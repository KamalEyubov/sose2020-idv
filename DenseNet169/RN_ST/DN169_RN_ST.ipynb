# %% [markdown]
# # Uploading data sets

# %%
from google.colab import drive

drive.mount('/content/drive/')

uploaded = ['/content/drive/My Drive/Images.zip',
            '/content/drive/My Drive/Data-split.zip',
            '/content/drive/My Drive/LUNA.zip']
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
#from google.colab import files

#uploaded = files.upload()

#for f in uploaded:
#    print('Uploaded: ' + f)

# %%
from zipfile import ZipFile

for f in uploaded:
    with ZipFile(f, 'r') as zip_ref:
        zip_ref.extractall('.')

# %% [markdown]
# # SSL on LUNA

# %%
import os

os.mkdir('ssl1_backup')
os.mkdir('ssl1_result')

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torch.nn as nn
import torch.optim as optim
from torchvision.models import densenet169 as DenseNet169
from PIL import Image
import numpy as np
from torch.utils.data import DataLoader, Dataset
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import torch.nn.functional as F

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)
np.random.seed(42)
torch.backends.cudnn.deterministic = True
rng = np.random.RandomState(42)

# %%
torch.cuda.empty_cache()

device = 'cuda'
batchsize = 4
train_epochs_start = 0
train_epochs_end = 50

# %%
class RotNet(nn.Module):

    def __init__(self, out_dim=4):
        super(RotNet, self).__init__()

        densenet = DenseNet169(pretrained=True)
        self.features = densenet.features
        self.relu = nn.ReLU(inplace=True)
        self.classifier = nn.Linear(
            densenet.classifier.in_features,
            out_features=out_dim,
            bias=True
        )

    def forward(self, x):
        out = self.features(x)
        out = self.relu(out)
        out = F.adaptive_avg_pool2d(out, (1, 1))
        out = torch.flatten(out, 1)
        out = self.classifier(out)
        return out

# %%
model = RotNet()
if device == 'cuda':
    model = model.cuda()
modelname = 'RotNet'

if train_epochs_start > 0:
    model.load_state_dict(
        torch.load('ssl1_backup/{}_{}.pt'.format(
            modelname,
            train_epochs_start
        ))
    )
# Out:
# Downloading: "https://download.pytorch.org/models/densenet169-b2777c0a.pth" to /root/.cache/torch/hub/checkpoints/densenet169-b2777c0a.pth
# HBox(children=(FloatProgress(value=0.0, max=57365526.0), HTML(value='')))

# %%
stages = ['ssl1', 'ssl2', 'fine-tuning']
stage_id = 0

def plot_change(model1, model2):
    global stage_id

    diff = torch.nn.MSELoss()
    norm_w, norm_wx, norm_b, norm_bx, conv_w, conv_wx = [], [], [], [], [], []
    i = 0
    for (name, parameter1), parameter2 in  zip(model1.named_parameters(), model2.parameters()):
        name = name.split(".")
        if name[-2][:4] == "conv":
            if name[-1] == "weight":
                conv_w.append(diff(parameter1, parameter2).item())
                conv_wx.append(i)
        elif name[-2][:4] == "norm":
            if name[-1] == "weight":
                norm_w.append(diff(parameter1, parameter2).item())
                norm_wx.append(i)
            elif name[-1] == "bias":
                norm_b.append(diff(parameter1, parameter2).item())
                norm_bx.append(i)
        i = i + 1

    plt.bar(norm_wx, norm_w, label="gamma")
    plt.bar(norm_bx, norm_b, label="beta")
    plt.legend()
    plt.title('Change of parameters at BN layers')
    plt.savefig(stages[stage_id] + '_bn_change.png')
    plt.show()

    plt.bar(conv_wx, conv_w)
    plt.title('Change of weights at CONV layers')
    plt.savefig(stages[stage_id] + '_conv_change.png')
    plt.show()

    stage_id = stage_id + 1

# %%
model_old = RotNet()
model_old.load_state_dict(model.state_dict())
# Out:
# <All keys matched successfully>

# %%
normalize = transforms.Normalize(
    mean=[0.3226, 0.3226, 0.3226],
    std=[0.3404, 0.3404, 0.3404]
)
transformer = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    normalize
])
def rotate(tensor, angle):
    if angle == 0:
        return tensor
    elif angle == 90:
        return tensor.transpose(-1, -2).flip((-2))
    elif angle == 180:
        return tensor.flip((-1, -2))
    elif angle == 270:
        return tensor.flip((-2)).transpose(-1, -2)
    else:
        return None

detransformer = torchvision.transforms.Compose([
    lambda image_tensor : image_tensor * torch.tensor([0.3226, 0.3226, 0.3226])[:, None, None],
    lambda image_tensor : image_tensor + torch.tensor([0.3404, 0.3404, 0.3404])[:, None, None],
    torchvision.transforms.ToPILImage()
])

# %%
def gradcam(model, input_tensor, detransform, label, axis):

	# Activations are saved.
	activations = dict() # one-key dictionary. Doesn't work otherwise.
	def get_activations(name):
		def hook(module, input, output):
			activations[name] = output.detach()
		return hook

	# Gradients are saved.
	grads = dict() # same as for activations
	def get_grads(name):
		def hook(module, grad_input, grad_output):
			grads[name] = grad_output[0].detach() # is a tuple
		return hook

	input_batch = input_tensor.unsqueeze(0) # a batch of one

	frw_handle = model.relu.register_forward_hook(get_activations("features"))
	bck_handle = model.relu.register_backward_hook(get_grads("features"))

	model.eval()
	model.zero_grad()
	output_batch = model(input_batch)
	output_batch[0][label].backward()

	frw_handle.remove()
	bck_handle.remove()

	activations = activations["features"]
	grads = grads["features"]

	grads = torch.mean(grads, dim=(-2, -1), keepdims=True) # gradients are pooled
	grad_cam = activations * grads
	grad_cam = torch.sum(grad_cam, dim=-3) # weighted sum
	grad_cam = torch.nn.functional.relu(grad_cam) # relu'd weighted sum
	grad_cam = grad_cam / grad_cam.max() # normalization
	grad_cam = grad_cam[0] # squeezing the batch of one

	axis.imshow(detransform(input_tensor).resize((224, 224)), alpha=1.0)
	# Grad-CAM is resized to 224x224 via bilinear interpolation and mapped to 'JET' colormap to be superimposed on the original image.
	axis.imshow(torchvision.transforms.ToPILImage()(grad_cam).resize((224, 224), resample=Image.BILINEAR), cmap='jet', alpha=0.5)
	axis.set_xticks([])
	axis.set_yticks([])

# %%
def read_txt(txt_path):
    with open(txt_path) as f:
        lines = f.readlines()
    txt_data = [line.strip() for line in lines]
    return txt_data

class LUNADataset(Dataset):
    def __init__(self, root_dir, transform=None):
        """
            Args:
                txt_path (string): Path to the txt file with annotations.
                root_dir (string): Directory with all the images.
                transform (callable, optional): Optional transform to be applied on a sample.
            File structure:
                - LUNA
                    - img1.png
                    - img2.png
                    - ......
        """
        self.img_list = [os.path.join(root_dir, item) for item in os.listdir(root_dir)]
        self.transform = transform

    def __len__(self):
        return len(self.img_list)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_path = self.img_list[idx]
        image = Image.open(img_path).convert('RGB')

        image = self.transform(image)
        image0 = rotate(image, 0)
        image1 = rotate(image, 90)
        image2 = rotate(image, 180)
        image3 = rotate(image, 270)

        sample = {
            'img0': image0, 'label0': 0,
            'img1': image1, 'label1': 1,
            'img2': image2, 'label2': 2,
            'img3': image3, 'label3': 3
        }
        return sample

# %%
dataset = LUNADataset(
    root_dir='LUNA',
    transform=transformer
)
print("dataset length:", dataset.__len__())
data_loader = DataLoader(dataset, batch_size=batchsize, drop_last=False, shuffle=True)
# Out:
# dataset length: 1000

# %%
def train(epoch):

    model.train()

    train_loss = 0

    for batch_index, batch_samples in enumerate(data_loader):

        # move data to device
        data0, label0 = batch_samples['img0'].to(device), batch_samples['label0'].to(device)
        data1, label1 = batch_samples['img1'].to(device), batch_samples['label1'].to(device)
        data2, label2 = batch_samples['img2'].to(device), batch_samples['label2'].to(device)
        data3, label3 = batch_samples['img3'].to(device), batch_samples['label3'].to(device)

        output0 = model(data0)
        output1 = model(data1)
        output2 = model(data2)
        output3 = model(data3)

        loss0 = criteria(output0, label0.long())
        loss1 = criteria(output1, label1.long())
        loss2 = criteria(output2, label2.long())
        loss3 = criteria(output3, label3.long())
        loss = (loss0 + loss1 + loss2 + loss3) / 4.
        train_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Display progress
        if (batch_index + 1) % bs == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]'.format(
                epoch,
                batch_index, len(data_loader),
                100.0 * batch_index / len(data_loader)
            ))

    avg_loss = train_loss / len(data_loader.dataset)
    print('Data set: Average loss: {:.4f}'.format(avg_loss))
    f = open('ssl1_result/train_{}.txt'.format(modelname), 'a+')
    f.write('Data set: Average loss: {:.4f}'.format(avg_loss))
    f.close()
    avg_losses.append(avg_loss)

# %%
bs = 10
T_checkpoint = 10
avg_losses = []

criteria = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

for epoch in range(train_epochs_start + 1, train_epochs_end + 1):
    train(epoch)
    
    if epoch % T_checkpoint == 0:
        # checkpoint
        torch.save(model.state_dict(), 'ssl1_backup/{}_{}.pt'.format(modelname, epoch))
# Out:
# Train Epoch: 1 [9/250 (4%)]
# Train Epoch: 1 [19/250 (8%)]
# Train Epoch: 1 [29/250 (12%)]
# Train Epoch: 1 [39/250 (16%)]
# Train Epoch: 1 [49/250 (20%)]
# Train Epoch: 1 [59/250 (24%)]
# Train Epoch: 1 [69/250 (28%)]
# Train Epoch: 1 [79/250 (32%)]
# Train Epoch: 1 [89/250 (36%)]
# Train Epoch: 1 [99/250 (40%)]
# Train Epoch: 1 [109/250 (44%)]
# Train Epoch: 1 [119/250 (48%)]
# Train Epoch: 1 [129/250 (52%)]
# Train Epoch: 1 [139/250 (56%)]
# Train Epoch: 1 [149/250 (60%)]
# Train Epoch: 1 [159/250 (64%)]
# Train Epoch: 1 [169/250 (68%)]
# Train Epoch: 1 [179/250 (72%)]
# Train Epoch: 1 [189/250 (76%)]
# Train Epoch: 1 [199/250 (80%)]
# Train Epoch: 1 [209/250 (84%)]
# Train Epoch: 1 [219/250 (88%)]
# Train Epoch: 1 [229/250 (92%)]
# Train Epoch: 1 [239/250 (96%)]
# Train Epoch: 1 [249/250 (100%)]
# Data set: Average loss: 0.0270
# Train Epoch: 2 [9/250 (4%)]
# Train Epoch: 2 [19/250 (8%)]
# Train Epoch: 2 [29/250 (12%)]
# Train Epoch: 2 [39/250 (16%)]
# Train Epoch: 2 [49/250 (20%)]
# Train Epoch: 2 [59/250 (24%)]
# Train Epoch: 2 [69/250 (28%)]
# Train Epoch: 2 [79/250 (32%)]
# Train Epoch: 2 [89/250 (36%)]
# Train Epoch: 2 [99/250 (40%)]
# Train Epoch: 2 [109/250 (44%)]
# Train Epoch: 2 [119/250 (48%)]
# Train Epoch: 2 [129/250 (52%)]
# Train Epoch: 2 [139/250 (56%)]
# Train Epoch: 2 [149/250 (60%)]
# Train Epoch: 2 [159/250 (64%)]
# Train Epoch: 2 [169/250 (68%)]
# Train Epoch: 2 [179/250 (72%)]
# Train Epoch: 2 [189/250 (76%)]
# Train Epoch: 2 [199/250 (80%)]
# Train Epoch: 2 [209/250 (84%)]
# Train Epoch: 2 [219/250 (88%)]
# Train Epoch: 2 [229/250 (92%)]
# Train Epoch: 2 [239/250 (96%)]
# Train Epoch: 2 [249/250 (100%)]
# Data set: Average loss: 0.0002
# Train Epoch: 3 [9/250 (4%)]
# Train Epoch: 3 [19/250 (8%)]
# Train Epoch: 3 [29/250 (12%)]
# Train Epoch: 3 [39/250 (16%)]
# Train Epoch: 3 [49/250 (20%)]
# Train Epoch: 3 [59/250 (24%)]
# Train Epoch: 3 [69/250 (28%)]
# Train Epoch: 3 [79/250 (32%)]
# Train Epoch: 3 [89/250 (36%)]
# Train Epoch: 3 [99/250 (40%)]
# Train Epoch: 3 [109/250 (44%)]
# Train Epoch: 3 [119/250 (48%)]
# Train Epoch: 3 [129/250 (52%)]
# Train Epoch: 3 [139/250 (56%)]
# Train Epoch: 3 [149/250 (60%)]
# Train Epoch: 3 [159/250 (64%)]
# Train Epoch: 3 [169/250 (68%)]
# Train Epoch: 3 [179/250 (72%)]
# Train Epoch: 3 [189/250 (76%)]
# Train Epoch: 3 [199/250 (80%)]
# Train Epoch: 3 [209/250 (84%)]
# Train Epoch: 3 [219/250 (88%)]
# Train Epoch: 3 [229/250 (92%)]
# Train Epoch: 3 [239/250 (96%)]
# Train Epoch: 3 [249/250 (100%)]
# Data set: Average loss: 0.0001
# Train Epoch: 4 [9/250 (4%)]
# Train Epoch: 4 [19/250 (8%)]
# Train Epoch: 4 [29/250 (12%)]
# Train Epoch: 4 [39/250 (16%)]
# Train Epoch: 4 [49/250 (20%)]
# Train Epoch: 4 [59/250 (24%)]
# Train Epoch: 4 [69/250 (28%)]
# Train Epoch: 4 [79/250 (32%)]
# Train Epoch: 4 [89/250 (36%)]
# Train Epoch: 4 [99/250 (40%)]
# Train Epoch: 4 [109/250 (44%)]
# Train Epoch: 4 [119/250 (48%)]
# Train Epoch: 4 [129/250 (52%)]
# Train Epoch: 4 [139/250 (56%)]
# Train Epoch: 4 [149/250 (60%)]
# Train Epoch: 4 [159/250 (64%)]
# Train Epoch: 4 [169/250 (68%)]
# Train Epoch: 4 [179/250 (72%)]
# Train Epoch: 4 [189/250 (76%)]
# Train Epoch: 4 [199/250 (80%)]
# Train Epoch: 4 [209/250 (84%)]
# Train Epoch: 4 [219/250 (88%)]
# Train Epoch: 4 [229/250 (92%)]
# Train Epoch: 4 [239/250 (96%)]
# Train Epoch: 4 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 5 [9/250 (4%)]
# Train Epoch: 5 [19/250 (8%)]
# Train Epoch: 5 [29/250 (12%)]
# Train Epoch: 5 [39/250 (16%)]
# Train Epoch: 5 [49/250 (20%)]
# Train Epoch: 5 [59/250 (24%)]
# Train Epoch: 5 [69/250 (28%)]
# Train Epoch: 5 [79/250 (32%)]
# Train Epoch: 5 [89/250 (36%)]
# Train Epoch: 5 [99/250 (40%)]
# Train Epoch: 5 [109/250 (44%)]
# Train Epoch: 5 [119/250 (48%)]
# Train Epoch: 5 [129/250 (52%)]
# Train Epoch: 5 [139/250 (56%)]
# Train Epoch: 5 [149/250 (60%)]
# Train Epoch: 5 [159/250 (64%)]
# Train Epoch: 5 [169/250 (68%)]
# Train Epoch: 5 [179/250 (72%)]
# Train Epoch: 5 [189/250 (76%)]
# Train Epoch: 5 [199/250 (80%)]
# Train Epoch: 5 [209/250 (84%)]
# Train Epoch: 5 [219/250 (88%)]
# Train Epoch: 5 [229/250 (92%)]
# Train Epoch: 5 [239/250 (96%)]
# Train Epoch: 5 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 6 [9/250 (4%)]
# Train Epoch: 6 [19/250 (8%)]
# Train Epoch: 6 [29/250 (12%)]
# Train Epoch: 6 [39/250 (16%)]
# Train Epoch: 6 [49/250 (20%)]
# Train Epoch: 6 [59/250 (24%)]
# Train Epoch: 6 [69/250 (28%)]
# Train Epoch: 6 [79/250 (32%)]
# Train Epoch: 6 [89/250 (36%)]
# Train Epoch: 6 [99/250 (40%)]
# Train Epoch: 6 [109/250 (44%)]
# Train Epoch: 6 [119/250 (48%)]
# Train Epoch: 6 [129/250 (52%)]
# Train Epoch: 6 [139/250 (56%)]
# Train Epoch: 6 [149/250 (60%)]
# Train Epoch: 6 [159/250 (64%)]
# Train Epoch: 6 [169/250 (68%)]
# Train Epoch: 6 [179/250 (72%)]
# Train Epoch: 6 [189/250 (76%)]
# Train Epoch: 6 [199/250 (80%)]
# Train Epoch: 6 [209/250 (84%)]
# Train Epoch: 6 [219/250 (88%)]
# Train Epoch: 6 [229/250 (92%)]
# Train Epoch: 6 [239/250 (96%)]
# Train Epoch: 6 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 7 [9/250 (4%)]
# Train Epoch: 7 [19/250 (8%)]
# Train Epoch: 7 [29/250 (12%)]
# Train Epoch: 7 [39/250 (16%)]
# Train Epoch: 7 [49/250 (20%)]
# Train Epoch: 7 [59/250 (24%)]
# Train Epoch: 7 [69/250 (28%)]
# Train Epoch: 7 [79/250 (32%)]
# Train Epoch: 7 [89/250 (36%)]
# Train Epoch: 7 [99/250 (40%)]
# Train Epoch: 7 [109/250 (44%)]
# Train Epoch: 7 [119/250 (48%)]
# Train Epoch: 7 [129/250 (52%)]
# Train Epoch: 7 [139/250 (56%)]
# Train Epoch: 7 [149/250 (60%)]
# Train Epoch: 7 [159/250 (64%)]
# Train Epoch: 7 [169/250 (68%)]
# Train Epoch: 7 [179/250 (72%)]
# Train Epoch: 7 [189/250 (76%)]
# Train Epoch: 7 [199/250 (80%)]
# Train Epoch: 7 [209/250 (84%)]
# Train Epoch: 7 [219/250 (88%)]
# Train Epoch: 7 [229/250 (92%)]
# Train Epoch: 7 [239/250 (96%)]
# Train Epoch: 7 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 8 [9/250 (4%)]
# Train Epoch: 8 [19/250 (8%)]
# Train Epoch: 8 [29/250 (12%)]
# Train Epoch: 8 [39/250 (16%)]
# Train Epoch: 8 [49/250 (20%)]
# Train Epoch: 8 [59/250 (24%)]
# Train Epoch: 8 [69/250 (28%)]
# Train Epoch: 8 [79/250 (32%)]
# Train Epoch: 8 [89/250 (36%)]
# Train Epoch: 8 [99/250 (40%)]
# Train Epoch: 8 [109/250 (44%)]
# Train Epoch: 8 [119/250 (48%)]
# Train Epoch: 8 [129/250 (52%)]
# Train Epoch: 8 [139/250 (56%)]
# Train Epoch: 8 [149/250 (60%)]
# Train Epoch: 8 [159/250 (64%)]
# Train Epoch: 8 [169/250 (68%)]
# Train Epoch: 8 [179/250 (72%)]
# Train Epoch: 8 [189/250 (76%)]
# Train Epoch: 8 [199/250 (80%)]
# Train Epoch: 8 [209/250 (84%)]
# Train Epoch: 8 [219/250 (88%)]
# Train Epoch: 8 [229/250 (92%)]
# Train Epoch: 8 [239/250 (96%)]
# Train Epoch: 8 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 9 [9/250 (4%)]
# Train Epoch: 9 [19/250 (8%)]
# Train Epoch: 9 [29/250 (12%)]
# Train Epoch: 9 [39/250 (16%)]
# Train Epoch: 9 [49/250 (20%)]
# Train Epoch: 9 [59/250 (24%)]
# Train Epoch: 9 [69/250 (28%)]
# Train Epoch: 9 [79/250 (32%)]
# Train Epoch: 9 [89/250 (36%)]
# Train Epoch: 9 [99/250 (40%)]
# Train Epoch: 9 [109/250 (44%)]
# Train Epoch: 9 [119/250 (48%)]
# Train Epoch: 9 [129/250 (52%)]
# Train Epoch: 9 [139/250 (56%)]
# Train Epoch: 9 [149/250 (60%)]
# Train Epoch: 9 [159/250 (64%)]
# Train Epoch: 9 [169/250 (68%)]
# Train Epoch: 9 [179/250 (72%)]
# Train Epoch: 9 [189/250 (76%)]
# Train Epoch: 9 [199/250 (80%)]
# Train Epoch: 9 [209/250 (84%)]
# Train Epoch: 9 [219/250 (88%)]
# Train Epoch: 9 [229/250 (92%)]
# Train Epoch: 9 [239/250 (96%)]
# Train Epoch: 9 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 10 [9/250 (4%)]
# Train Epoch: 10 [19/250 (8%)]
# Train Epoch: 10 [29/250 (12%)]
# Train Epoch: 10 [39/250 (16%)]
# Train Epoch: 10 [49/250 (20%)]
# Train Epoch: 10 [59/250 (24%)]
# Train Epoch: 10 [69/250 (28%)]
# Train Epoch: 10 [79/250 (32%)]
# Train Epoch: 10 [89/250 (36%)]
# Train Epoch: 10 [99/250 (40%)]
# Train Epoch: 10 [109/250 (44%)]
# Train Epoch: 10 [119/250 (48%)]
# Train Epoch: 10 [129/250 (52%)]
# Train Epoch: 10 [139/250 (56%)]
# Train Epoch: 10 [149/250 (60%)]
# Train Epoch: 10 [159/250 (64%)]
# Train Epoch: 10 [169/250 (68%)]
# Train Epoch: 10 [179/250 (72%)]
# Train Epoch: 10 [189/250 (76%)]
# Train Epoch: 10 [199/250 (80%)]
# Train Epoch: 10 [209/250 (84%)]
# Train Epoch: 10 [219/250 (88%)]
# Train Epoch: 10 [229/250 (92%)]
# Train Epoch: 10 [239/250 (96%)]
# Train Epoch: 10 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 11 [9/250 (4%)]
# Train Epoch: 11 [19/250 (8%)]
# Train Epoch: 11 [29/250 (12%)]
# Train Epoch: 11 [39/250 (16%)]
# Train Epoch: 11 [49/250 (20%)]
# Train Epoch: 11 [59/250 (24%)]
# Train Epoch: 11 [69/250 (28%)]
# Train Epoch: 11 [79/250 (32%)]
# Train Epoch: 11 [89/250 (36%)]
# Train Epoch: 11 [99/250 (40%)]
# Train Epoch: 11 [109/250 (44%)]
# Train Epoch: 11 [119/250 (48%)]
# Train Epoch: 11 [129/250 (52%)]
# Train Epoch: 11 [139/250 (56%)]
# Train Epoch: 11 [149/250 (60%)]
# Train Epoch: 11 [159/250 (64%)]
# Train Epoch: 11 [169/250 (68%)]
# Train Epoch: 11 [179/250 (72%)]
# Train Epoch: 11 [189/250 (76%)]
# Train Epoch: 11 [199/250 (80%)]
# Train Epoch: 11 [209/250 (84%)]
# Train Epoch: 11 [219/250 (88%)]
# Train Epoch: 11 [229/250 (92%)]
# Train Epoch: 11 [239/250 (96%)]
# Train Epoch: 11 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 12 [9/250 (4%)]
# Train Epoch: 12 [19/250 (8%)]
# Train Epoch: 12 [29/250 (12%)]
# Train Epoch: 12 [39/250 (16%)]
# Train Epoch: 12 [49/250 (20%)]
# Train Epoch: 12 [59/250 (24%)]
# Train Epoch: 12 [69/250 (28%)]
# Train Epoch: 12 [79/250 (32%)]
# Train Epoch: 12 [89/250 (36%)]
# Train Epoch: 12 [99/250 (40%)]
# Train Epoch: 12 [109/250 (44%)]
# Train Epoch: 12 [119/250 (48%)]
# Train Epoch: 12 [129/250 (52%)]
# Train Epoch: 12 [139/250 (56%)]
# Train Epoch: 12 [149/250 (60%)]
# Train Epoch: 12 [159/250 (64%)]
# Train Epoch: 12 [169/250 (68%)]
# Train Epoch: 12 [179/250 (72%)]
# Train Epoch: 12 [189/250 (76%)]
# Train Epoch: 12 [199/250 (80%)]
# Train Epoch: 12 [209/250 (84%)]
# Train Epoch: 12 [219/250 (88%)]
# Train Epoch: 12 [229/250 (92%)]
# Train Epoch: 12 [239/250 (96%)]
# Train Epoch: 12 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 13 [9/250 (4%)]
# Train Epoch: 13 [19/250 (8%)]
# Train Epoch: 13 [29/250 (12%)]
# Train Epoch: 13 [39/250 (16%)]
# Train Epoch: 13 [49/250 (20%)]
# Train Epoch: 13 [59/250 (24%)]
# Train Epoch: 13 [69/250 (28%)]
# Train Epoch: 13 [79/250 (32%)]
# Train Epoch: 13 [89/250 (36%)]
# Train Epoch: 13 [99/250 (40%)]
# Train Epoch: 13 [109/250 (44%)]
# Train Epoch: 13 [119/250 (48%)]
# Train Epoch: 13 [129/250 (52%)]
# Train Epoch: 13 [139/250 (56%)]
# Train Epoch: 13 [149/250 (60%)]
# Train Epoch: 13 [159/250 (64%)]
# Train Epoch: 13 [169/250 (68%)]
# Train Epoch: 13 [179/250 (72%)]
# Train Epoch: 13 [189/250 (76%)]
# Train Epoch: 13 [199/250 (80%)]
# Train Epoch: 13 [209/250 (84%)]
# Train Epoch: 13 [219/250 (88%)]
# Train Epoch: 13 [229/250 (92%)]
# Train Epoch: 13 [239/250 (96%)]
# Train Epoch: 13 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 14 [9/250 (4%)]
# Train Epoch: 14 [19/250 (8%)]
# Train Epoch: 14 [29/250 (12%)]
# Train Epoch: 14 [39/250 (16%)]
# Train Epoch: 14 [49/250 (20%)]
# Train Epoch: 14 [59/250 (24%)]
# Train Epoch: 14 [69/250 (28%)]
# Train Epoch: 14 [79/250 (32%)]
# Train Epoch: 14 [89/250 (36%)]
# Train Epoch: 14 [99/250 (40%)]
# Train Epoch: 14 [109/250 (44%)]
# Train Epoch: 14 [119/250 (48%)]
# Train Epoch: 14 [129/250 (52%)]
# Train Epoch: 14 [139/250 (56%)]
# Train Epoch: 14 [149/250 (60%)]
# Train Epoch: 14 [159/250 (64%)]
# Train Epoch: 14 [169/250 (68%)]
# Train Epoch: 14 [179/250 (72%)]
# Train Epoch: 14 [189/250 (76%)]
# Train Epoch: 14 [199/250 (80%)]
# Train Epoch: 14 [209/250 (84%)]
# Train Epoch: 14 [219/250 (88%)]
# Train Epoch: 14 [229/250 (92%)]
# Train Epoch: 14 [239/250 (96%)]
# Train Epoch: 14 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 15 [9/250 (4%)]
# Train Epoch: 15 [19/250 (8%)]
# Train Epoch: 15 [29/250 (12%)]
# Train Epoch: 15 [39/250 (16%)]
# Train Epoch: 15 [49/250 (20%)]
# Train Epoch: 15 [59/250 (24%)]
# Train Epoch: 15 [69/250 (28%)]
# Train Epoch: 15 [79/250 (32%)]
# Train Epoch: 15 [89/250 (36%)]
# Train Epoch: 15 [99/250 (40%)]
# Train Epoch: 15 [109/250 (44%)]
# Train Epoch: 15 [119/250 (48%)]
# Train Epoch: 15 [129/250 (52%)]
# Train Epoch: 15 [139/250 (56%)]
# Train Epoch: 15 [149/250 (60%)]
# Train Epoch: 15 [159/250 (64%)]
# Train Epoch: 15 [169/250 (68%)]
# Train Epoch: 15 [179/250 (72%)]
# Train Epoch: 15 [189/250 (76%)]
# Train Epoch: 15 [199/250 (80%)]
# Train Epoch: 15 [209/250 (84%)]
# Train Epoch: 15 [219/250 (88%)]
# Train Epoch: 15 [229/250 (92%)]
# Train Epoch: 15 [239/250 (96%)]
# Train Epoch: 15 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 16 [9/250 (4%)]
# Train Epoch: 16 [19/250 (8%)]
# Train Epoch: 16 [29/250 (12%)]
# Train Epoch: 16 [39/250 (16%)]
# Train Epoch: 16 [49/250 (20%)]
# Train Epoch: 16 [59/250 (24%)]
# Train Epoch: 16 [69/250 (28%)]
# Train Epoch: 16 [79/250 (32%)]
# Train Epoch: 16 [89/250 (36%)]
# Train Epoch: 16 [99/250 (40%)]
# Train Epoch: 16 [109/250 (44%)]
# Train Epoch: 16 [119/250 (48%)]
# Train Epoch: 16 [129/250 (52%)]
# Train Epoch: 16 [139/250 (56%)]
# Train Epoch: 16 [149/250 (60%)]
# Train Epoch: 16 [159/250 (64%)]
# Train Epoch: 16 [169/250 (68%)]
# Train Epoch: 16 [179/250 (72%)]
# Train Epoch: 16 [189/250 (76%)]
# Train Epoch: 16 [199/250 (80%)]
# Train Epoch: 16 [209/250 (84%)]
# Train Epoch: 16 [219/250 (88%)]
# Train Epoch: 16 [229/250 (92%)]
# Train Epoch: 16 [239/250 (96%)]
# Train Epoch: 16 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 17 [9/250 (4%)]
# Train Epoch: 17 [19/250 (8%)]
# Train Epoch: 17 [29/250 (12%)]
# Train Epoch: 17 [39/250 (16%)]
# Train Epoch: 17 [49/250 (20%)]
# Train Epoch: 17 [59/250 (24%)]
# Train Epoch: 17 [69/250 (28%)]
# Train Epoch: 17 [79/250 (32%)]
# Train Epoch: 17 [89/250 (36%)]
# Train Epoch: 17 [99/250 (40%)]
# Train Epoch: 17 [109/250 (44%)]
# Train Epoch: 17 [119/250 (48%)]
# Train Epoch: 17 [129/250 (52%)]
# Train Epoch: 17 [139/250 (56%)]
# Train Epoch: 17 [149/250 (60%)]
# Train Epoch: 17 [159/250 (64%)]
# Train Epoch: 17 [169/250 (68%)]
# Train Epoch: 17 [179/250 (72%)]
# Train Epoch: 17 [189/250 (76%)]
# Train Epoch: 17 [199/250 (80%)]
# Train Epoch: 17 [209/250 (84%)]
# Train Epoch: 17 [219/250 (88%)]
# Train Epoch: 17 [229/250 (92%)]
# Train Epoch: 17 [239/250 (96%)]
# Train Epoch: 17 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 18 [9/250 (4%)]
# Train Epoch: 18 [19/250 (8%)]
# Train Epoch: 18 [29/250 (12%)]
# Train Epoch: 18 [39/250 (16%)]
# Train Epoch: 18 [49/250 (20%)]
# Train Epoch: 18 [59/250 (24%)]
# Train Epoch: 18 [69/250 (28%)]
# Train Epoch: 18 [79/250 (32%)]
# Train Epoch: 18 [89/250 (36%)]
# Train Epoch: 18 [99/250 (40%)]
# Train Epoch: 18 [109/250 (44%)]
# Train Epoch: 18 [119/250 (48%)]
# Train Epoch: 18 [129/250 (52%)]
# Train Epoch: 18 [139/250 (56%)]
# Train Epoch: 18 [149/250 (60%)]
# Train Epoch: 18 [159/250 (64%)]
# Train Epoch: 18 [169/250 (68%)]
# Train Epoch: 18 [179/250 (72%)]
# Train Epoch: 18 [189/250 (76%)]
# Train Epoch: 18 [199/250 (80%)]
# Train Epoch: 18 [209/250 (84%)]
# Train Epoch: 18 [219/250 (88%)]
# Train Epoch: 18 [229/250 (92%)]
# Train Epoch: 18 [239/250 (96%)]
# Train Epoch: 18 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 19 [9/250 (4%)]
# Train Epoch: 19 [19/250 (8%)]
# Train Epoch: 19 [29/250 (12%)]
# Train Epoch: 19 [39/250 (16%)]
# Train Epoch: 19 [49/250 (20%)]
# Train Epoch: 19 [59/250 (24%)]
# Train Epoch: 19 [69/250 (28%)]
# Train Epoch: 19 [79/250 (32%)]
# Train Epoch: 19 [89/250 (36%)]
# Train Epoch: 19 [99/250 (40%)]
# Train Epoch: 19 [109/250 (44%)]
# Train Epoch: 19 [119/250 (48%)]
# Train Epoch: 19 [129/250 (52%)]
# Train Epoch: 19 [139/250 (56%)]
# Train Epoch: 19 [149/250 (60%)]
# Train Epoch: 19 [159/250 (64%)]
# Train Epoch: 19 [169/250 (68%)]
# Train Epoch: 19 [179/250 (72%)]
# Train Epoch: 19 [189/250 (76%)]
# Train Epoch: 19 [199/250 (80%)]
# Train Epoch: 19 [209/250 (84%)]
# Train Epoch: 19 [219/250 (88%)]
# Train Epoch: 19 [229/250 (92%)]
# Train Epoch: 19 [239/250 (96%)]
# Train Epoch: 19 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 20 [9/250 (4%)]
# Train Epoch: 20 [19/250 (8%)]
# Train Epoch: 20 [29/250 (12%)]
# Train Epoch: 20 [39/250 (16%)]
# Train Epoch: 20 [49/250 (20%)]
# Train Epoch: 20 [59/250 (24%)]
# Train Epoch: 20 [69/250 (28%)]
# Train Epoch: 20 [79/250 (32%)]
# Train Epoch: 20 [89/250 (36%)]
# Train Epoch: 20 [99/250 (40%)]
# Train Epoch: 20 [109/250 (44%)]
# Train Epoch: 20 [119/250 (48%)]
# Train Epoch: 20 [129/250 (52%)]
# Train Epoch: 20 [139/250 (56%)]
# Train Epoch: 20 [149/250 (60%)]
# Train Epoch: 20 [159/250 (64%)]
# Train Epoch: 20 [169/250 (68%)]
# Train Epoch: 20 [179/250 (72%)]
# Train Epoch: 20 [189/250 (76%)]
# Train Epoch: 20 [199/250 (80%)]
# Train Epoch: 20 [209/250 (84%)]
# Train Epoch: 20 [219/250 (88%)]
# Train Epoch: 20 [229/250 (92%)]
# Train Epoch: 20 [239/250 (96%)]
# Train Epoch: 20 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 21 [9/250 (4%)]
# Train Epoch: 21 [19/250 (8%)]
# Train Epoch: 21 [29/250 (12%)]
# Train Epoch: 21 [39/250 (16%)]
# Train Epoch: 21 [49/250 (20%)]
# Train Epoch: 21 [59/250 (24%)]
# Train Epoch: 21 [69/250 (28%)]
# Train Epoch: 21 [79/250 (32%)]
# Train Epoch: 21 [89/250 (36%)]
# Train Epoch: 21 [99/250 (40%)]
# Train Epoch: 21 [109/250 (44%)]
# Train Epoch: 21 [119/250 (48%)]
# Train Epoch: 21 [129/250 (52%)]
# Train Epoch: 21 [139/250 (56%)]
# Train Epoch: 21 [149/250 (60%)]
# Train Epoch: 21 [159/250 (64%)]
# Train Epoch: 21 [169/250 (68%)]
# Train Epoch: 21 [179/250 (72%)]
# Train Epoch: 21 [189/250 (76%)]
# Train Epoch: 21 [199/250 (80%)]
# Train Epoch: 21 [209/250 (84%)]
# Train Epoch: 21 [219/250 (88%)]
# Train Epoch: 21 [229/250 (92%)]
# Train Epoch: 21 [239/250 (96%)]
# Train Epoch: 21 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 22 [9/250 (4%)]
# Train Epoch: 22 [19/250 (8%)]
# Train Epoch: 22 [29/250 (12%)]
# Train Epoch: 22 [39/250 (16%)]
# Train Epoch: 22 [49/250 (20%)]
# Train Epoch: 22 [59/250 (24%)]
# Train Epoch: 22 [69/250 (28%)]
# Train Epoch: 22 [79/250 (32%)]
# Train Epoch: 22 [89/250 (36%)]
# Train Epoch: 22 [99/250 (40%)]
# Train Epoch: 22 [109/250 (44%)]
# Train Epoch: 22 [119/250 (48%)]
# Train Epoch: 22 [129/250 (52%)]
# Train Epoch: 22 [139/250 (56%)]
# Train Epoch: 22 [149/250 (60%)]
# Train Epoch: 22 [159/250 (64%)]
# Train Epoch: 22 [169/250 (68%)]
# Train Epoch: 22 [179/250 (72%)]
# Train Epoch: 22 [189/250 (76%)]
# Train Epoch: 22 [199/250 (80%)]
# Train Epoch: 22 [209/250 (84%)]
# Train Epoch: 22 [219/250 (88%)]
# Train Epoch: 22 [229/250 (92%)]
# Train Epoch: 22 [239/250 (96%)]
# Train Epoch: 22 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 23 [9/250 (4%)]
# Train Epoch: 23 [19/250 (8%)]
# Train Epoch: 23 [29/250 (12%)]
# Train Epoch: 23 [39/250 (16%)]
# Train Epoch: 23 [49/250 (20%)]
# Train Epoch: 23 [59/250 (24%)]
# Train Epoch: 23 [69/250 (28%)]
# Train Epoch: 23 [79/250 (32%)]
# Train Epoch: 23 [89/250 (36%)]
# Train Epoch: 23 [99/250 (40%)]
# Train Epoch: 23 [109/250 (44%)]
# Train Epoch: 23 [119/250 (48%)]
# Train Epoch: 23 [129/250 (52%)]
# Train Epoch: 23 [139/250 (56%)]
# Train Epoch: 23 [149/250 (60%)]
# Train Epoch: 23 [159/250 (64%)]
# Train Epoch: 23 [169/250 (68%)]
# Train Epoch: 23 [179/250 (72%)]
# Train Epoch: 23 [189/250 (76%)]
# Train Epoch: 23 [199/250 (80%)]
# Train Epoch: 23 [209/250 (84%)]
# Train Epoch: 23 [219/250 (88%)]
# Train Epoch: 23 [229/250 (92%)]
# Train Epoch: 23 [239/250 (96%)]
# Train Epoch: 23 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 24 [9/250 (4%)]
# Train Epoch: 24 [19/250 (8%)]
# Train Epoch: 24 [29/250 (12%)]
# Train Epoch: 24 [39/250 (16%)]
# Train Epoch: 24 [49/250 (20%)]
# Train Epoch: 24 [59/250 (24%)]
# Train Epoch: 24 [69/250 (28%)]
# Train Epoch: 24 [79/250 (32%)]
# Train Epoch: 24 [89/250 (36%)]
# Train Epoch: 24 [99/250 (40%)]
# Train Epoch: 24 [109/250 (44%)]
# Train Epoch: 24 [119/250 (48%)]
# Train Epoch: 24 [129/250 (52%)]
# Train Epoch: 24 [139/250 (56%)]
# Train Epoch: 24 [149/250 (60%)]
# Train Epoch: 24 [159/250 (64%)]
# Train Epoch: 24 [169/250 (68%)]
# Train Epoch: 24 [179/250 (72%)]
# Train Epoch: 24 [189/250 (76%)]
# Train Epoch: 24 [199/250 (80%)]
# Train Epoch: 24 [209/250 (84%)]
# Train Epoch: 24 [219/250 (88%)]
# Train Epoch: 24 [229/250 (92%)]
# Train Epoch: 24 [239/250 (96%)]
# Train Epoch: 24 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 25 [9/250 (4%)]
# Train Epoch: 25 [19/250 (8%)]
# Train Epoch: 25 [29/250 (12%)]
# Train Epoch: 25 [39/250 (16%)]
# Train Epoch: 25 [49/250 (20%)]
# Train Epoch: 25 [59/250 (24%)]
# Train Epoch: 25 [69/250 (28%)]
# Train Epoch: 25 [79/250 (32%)]
# Train Epoch: 25 [89/250 (36%)]
# Train Epoch: 25 [99/250 (40%)]
# Train Epoch: 25 [109/250 (44%)]
# Train Epoch: 25 [119/250 (48%)]
# Train Epoch: 25 [129/250 (52%)]
# Train Epoch: 25 [139/250 (56%)]
# Train Epoch: 25 [149/250 (60%)]
# Train Epoch: 25 [159/250 (64%)]
# Train Epoch: 25 [169/250 (68%)]
# Train Epoch: 25 [179/250 (72%)]
# Train Epoch: 25 [189/250 (76%)]
# Train Epoch: 25 [199/250 (80%)]
# Train Epoch: 25 [209/250 (84%)]
# Train Epoch: 25 [219/250 (88%)]
# Train Epoch: 25 [229/250 (92%)]
# Train Epoch: 25 [239/250 (96%)]
# Train Epoch: 25 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 26 [9/250 (4%)]
# Train Epoch: 26 [19/250 (8%)]
# Train Epoch: 26 [29/250 (12%)]
# Train Epoch: 26 [39/250 (16%)]
# Train Epoch: 26 [49/250 (20%)]
# Train Epoch: 26 [59/250 (24%)]
# Train Epoch: 26 [69/250 (28%)]
# Train Epoch: 26 [79/250 (32%)]
# Train Epoch: 26 [89/250 (36%)]
# Train Epoch: 26 [99/250 (40%)]
# Train Epoch: 26 [109/250 (44%)]
# Train Epoch: 26 [119/250 (48%)]
# Train Epoch: 26 [129/250 (52%)]
# Train Epoch: 26 [139/250 (56%)]
# Train Epoch: 26 [149/250 (60%)]
# Train Epoch: 26 [159/250 (64%)]
# Train Epoch: 26 [169/250 (68%)]
# Train Epoch: 26 [179/250 (72%)]
# Train Epoch: 26 [189/250 (76%)]
# Train Epoch: 26 [199/250 (80%)]
# Train Epoch: 26 [209/250 (84%)]
# Train Epoch: 26 [219/250 (88%)]
# Train Epoch: 26 [229/250 (92%)]
# Train Epoch: 26 [239/250 (96%)]
# Train Epoch: 26 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 27 [9/250 (4%)]
# Train Epoch: 27 [19/250 (8%)]
# Train Epoch: 27 [29/250 (12%)]
# Train Epoch: 27 [39/250 (16%)]
# Train Epoch: 27 [49/250 (20%)]
# Train Epoch: 27 [59/250 (24%)]
# Train Epoch: 27 [69/250 (28%)]
# Train Epoch: 27 [79/250 (32%)]
# Train Epoch: 27 [89/250 (36%)]
# Train Epoch: 27 [99/250 (40%)]
# Train Epoch: 27 [109/250 (44%)]
# Train Epoch: 27 [119/250 (48%)]
# Train Epoch: 27 [129/250 (52%)]
# Train Epoch: 27 [139/250 (56%)]
# Train Epoch: 27 [149/250 (60%)]
# Train Epoch: 27 [159/250 (64%)]
# Train Epoch: 27 [169/250 (68%)]
# Train Epoch: 27 [179/250 (72%)]
# Train Epoch: 27 [189/250 (76%)]
# Train Epoch: 27 [199/250 (80%)]
# Train Epoch: 27 [209/250 (84%)]
# Train Epoch: 27 [219/250 (88%)]
# Train Epoch: 27 [229/250 (92%)]
# Train Epoch: 27 [239/250 (96%)]
# Train Epoch: 27 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 28 [9/250 (4%)]
# Train Epoch: 28 [19/250 (8%)]
# Train Epoch: 28 [29/250 (12%)]
# Train Epoch: 28 [39/250 (16%)]
# Train Epoch: 28 [49/250 (20%)]
# Train Epoch: 28 [59/250 (24%)]
# Train Epoch: 28 [69/250 (28%)]
# Train Epoch: 28 [79/250 (32%)]
# Train Epoch: 28 [89/250 (36%)]
# Train Epoch: 28 [99/250 (40%)]
# Train Epoch: 28 [109/250 (44%)]
# Train Epoch: 28 [119/250 (48%)]
# Train Epoch: 28 [129/250 (52%)]
# Train Epoch: 28 [139/250 (56%)]
# Train Epoch: 28 [149/250 (60%)]
# Train Epoch: 28 [159/250 (64%)]
# Train Epoch: 28 [169/250 (68%)]
# Train Epoch: 28 [179/250 (72%)]
# Train Epoch: 28 [189/250 (76%)]
# Train Epoch: 28 [199/250 (80%)]
# Train Epoch: 28 [209/250 (84%)]
# Train Epoch: 28 [219/250 (88%)]
# Train Epoch: 28 [229/250 (92%)]
# Train Epoch: 28 [239/250 (96%)]
# Train Epoch: 28 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 29 [9/250 (4%)]
# Train Epoch: 29 [19/250 (8%)]
# Train Epoch: 29 [29/250 (12%)]
# Train Epoch: 29 [39/250 (16%)]
# Train Epoch: 29 [49/250 (20%)]
# Train Epoch: 29 [59/250 (24%)]
# Train Epoch: 29 [69/250 (28%)]
# Train Epoch: 29 [79/250 (32%)]
# Train Epoch: 29 [89/250 (36%)]
# Train Epoch: 29 [99/250 (40%)]
# Train Epoch: 29 [109/250 (44%)]
# Train Epoch: 29 [119/250 (48%)]
# Train Epoch: 29 [129/250 (52%)]
# Train Epoch: 29 [139/250 (56%)]
# Train Epoch: 29 [149/250 (60%)]
# Train Epoch: 29 [159/250 (64%)]
# Train Epoch: 29 [169/250 (68%)]
# Train Epoch: 29 [179/250 (72%)]
# Train Epoch: 29 [189/250 (76%)]
# Train Epoch: 29 [199/250 (80%)]
# Train Epoch: 29 [209/250 (84%)]
# Train Epoch: 29 [219/250 (88%)]
# Train Epoch: 29 [229/250 (92%)]
# Train Epoch: 29 [239/250 (96%)]
# Train Epoch: 29 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 30 [9/250 (4%)]
# Train Epoch: 30 [19/250 (8%)]
# Train Epoch: 30 [29/250 (12%)]
# Train Epoch: 30 [39/250 (16%)]
# Train Epoch: 30 [49/250 (20%)]
# Train Epoch: 30 [59/250 (24%)]
# Train Epoch: 30 [69/250 (28%)]
# Train Epoch: 30 [79/250 (32%)]
# Train Epoch: 30 [89/250 (36%)]
# Train Epoch: 30 [99/250 (40%)]
# Train Epoch: 30 [109/250 (44%)]
# Train Epoch: 30 [119/250 (48%)]
# Train Epoch: 30 [129/250 (52%)]
# Train Epoch: 30 [139/250 (56%)]
# Train Epoch: 30 [149/250 (60%)]
# Train Epoch: 30 [159/250 (64%)]
# Train Epoch: 30 [169/250 (68%)]
# Train Epoch: 30 [179/250 (72%)]
# Train Epoch: 30 [189/250 (76%)]
# Train Epoch: 30 [199/250 (80%)]
# Train Epoch: 30 [209/250 (84%)]
# Train Epoch: 30 [219/250 (88%)]
# Train Epoch: 30 [229/250 (92%)]
# Train Epoch: 30 [239/250 (96%)]
# Train Epoch: 30 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 31 [9/250 (4%)]
# Train Epoch: 31 [19/250 (8%)]
# Train Epoch: 31 [29/250 (12%)]
# Train Epoch: 31 [39/250 (16%)]
# Train Epoch: 31 [49/250 (20%)]
# Train Epoch: 31 [59/250 (24%)]
# Train Epoch: 31 [69/250 (28%)]
# Train Epoch: 31 [79/250 (32%)]
# Train Epoch: 31 [89/250 (36%)]
# Train Epoch: 31 [99/250 (40%)]
# Train Epoch: 31 [109/250 (44%)]
# Train Epoch: 31 [119/250 (48%)]
# Train Epoch: 31 [129/250 (52%)]
# Train Epoch: 31 [139/250 (56%)]
# Train Epoch: 31 [149/250 (60%)]
# Train Epoch: 31 [159/250 (64%)]
# Train Epoch: 31 [169/250 (68%)]
# Train Epoch: 31 [179/250 (72%)]
# Train Epoch: 31 [189/250 (76%)]
# Train Epoch: 31 [199/250 (80%)]
# Train Epoch: 31 [209/250 (84%)]
# Train Epoch: 31 [219/250 (88%)]
# Train Epoch: 31 [229/250 (92%)]
# Train Epoch: 31 [239/250 (96%)]
# Train Epoch: 31 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 32 [9/250 (4%)]
# Train Epoch: 32 [19/250 (8%)]
# Train Epoch: 32 [29/250 (12%)]
# Train Epoch: 32 [39/250 (16%)]
# Train Epoch: 32 [49/250 (20%)]
# Train Epoch: 32 [59/250 (24%)]
# Train Epoch: 32 [69/250 (28%)]
# Train Epoch: 32 [79/250 (32%)]
# Train Epoch: 32 [89/250 (36%)]
# Train Epoch: 32 [99/250 (40%)]
# Train Epoch: 32 [109/250 (44%)]
# Train Epoch: 32 [119/250 (48%)]
# Train Epoch: 32 [129/250 (52%)]
# Train Epoch: 32 [139/250 (56%)]
# Train Epoch: 32 [149/250 (60%)]
# Train Epoch: 32 [159/250 (64%)]
# Train Epoch: 32 [169/250 (68%)]
# Train Epoch: 32 [179/250 (72%)]
# Train Epoch: 32 [189/250 (76%)]
# Train Epoch: 32 [199/250 (80%)]
# Train Epoch: 32 [209/250 (84%)]
# Train Epoch: 32 [219/250 (88%)]
# Train Epoch: 32 [229/250 (92%)]
# Train Epoch: 32 [239/250 (96%)]
# Train Epoch: 32 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 33 [9/250 (4%)]
# Train Epoch: 33 [19/250 (8%)]
# Train Epoch: 33 [29/250 (12%)]
# Train Epoch: 33 [39/250 (16%)]
# Train Epoch: 33 [49/250 (20%)]
# Train Epoch: 33 [59/250 (24%)]
# Train Epoch: 33 [69/250 (28%)]
# Train Epoch: 33 [79/250 (32%)]
# Train Epoch: 33 [89/250 (36%)]
# Train Epoch: 33 [99/250 (40%)]
# Train Epoch: 33 [109/250 (44%)]
# Train Epoch: 33 [119/250 (48%)]
# Train Epoch: 33 [129/250 (52%)]
# Train Epoch: 33 [139/250 (56%)]
# Train Epoch: 33 [149/250 (60%)]
# Train Epoch: 33 [159/250 (64%)]
# Train Epoch: 33 [169/250 (68%)]
# Train Epoch: 33 [179/250 (72%)]
# Train Epoch: 33 [189/250 (76%)]
# Train Epoch: 33 [199/250 (80%)]
# Train Epoch: 33 [209/250 (84%)]
# Train Epoch: 33 [219/250 (88%)]
# Train Epoch: 33 [229/250 (92%)]
# Train Epoch: 33 [239/250 (96%)]
# Train Epoch: 33 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 34 [9/250 (4%)]
# Train Epoch: 34 [19/250 (8%)]
# Train Epoch: 34 [29/250 (12%)]
# Train Epoch: 34 [39/250 (16%)]
# Train Epoch: 34 [49/250 (20%)]
# Train Epoch: 34 [59/250 (24%)]
# Train Epoch: 34 [69/250 (28%)]
# Train Epoch: 34 [79/250 (32%)]
# Train Epoch: 34 [89/250 (36%)]
# Train Epoch: 34 [99/250 (40%)]
# Train Epoch: 34 [109/250 (44%)]
# Train Epoch: 34 [119/250 (48%)]
# Train Epoch: 34 [129/250 (52%)]
# Train Epoch: 34 [139/250 (56%)]
# Train Epoch: 34 [149/250 (60%)]
# Train Epoch: 34 [159/250 (64%)]
# Train Epoch: 34 [169/250 (68%)]
# Train Epoch: 34 [179/250 (72%)]
# Train Epoch: 34 [189/250 (76%)]
# Train Epoch: 34 [199/250 (80%)]
# Train Epoch: 34 [209/250 (84%)]
# Train Epoch: 34 [219/250 (88%)]
# Train Epoch: 34 [229/250 (92%)]
# Train Epoch: 34 [239/250 (96%)]
# Train Epoch: 34 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 35 [9/250 (4%)]
# Train Epoch: 35 [19/250 (8%)]
# Train Epoch: 35 [29/250 (12%)]
# Train Epoch: 35 [39/250 (16%)]
# Train Epoch: 35 [49/250 (20%)]
# Train Epoch: 35 [59/250 (24%)]
# Train Epoch: 35 [69/250 (28%)]
# Train Epoch: 35 [79/250 (32%)]
# Train Epoch: 35 [89/250 (36%)]
# Train Epoch: 35 [99/250 (40%)]
# Train Epoch: 35 [109/250 (44%)]
# Train Epoch: 35 [119/250 (48%)]
# Train Epoch: 35 [129/250 (52%)]
# Train Epoch: 35 [139/250 (56%)]
# Train Epoch: 35 [149/250 (60%)]
# Train Epoch: 35 [159/250 (64%)]
# Train Epoch: 35 [169/250 (68%)]
# Train Epoch: 35 [179/250 (72%)]
# Train Epoch: 35 [189/250 (76%)]
# Train Epoch: 35 [199/250 (80%)]
# Train Epoch: 35 [209/250 (84%)]
# Train Epoch: 35 [219/250 (88%)]
# Train Epoch: 35 [229/250 (92%)]
# Train Epoch: 35 [239/250 (96%)]
# Train Epoch: 35 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 36 [9/250 (4%)]
# Train Epoch: 36 [19/250 (8%)]
# Train Epoch: 36 [29/250 (12%)]
# Train Epoch: 36 [39/250 (16%)]
# Train Epoch: 36 [49/250 (20%)]
# Train Epoch: 36 [59/250 (24%)]
# Train Epoch: 36 [69/250 (28%)]
# Train Epoch: 36 [79/250 (32%)]
# Train Epoch: 36 [89/250 (36%)]
# Train Epoch: 36 [99/250 (40%)]
# Train Epoch: 36 [109/250 (44%)]
# Train Epoch: 36 [119/250 (48%)]
# Train Epoch: 36 [129/250 (52%)]
# Train Epoch: 36 [139/250 (56%)]
# Train Epoch: 36 [149/250 (60%)]
# Train Epoch: 36 [159/250 (64%)]
# Train Epoch: 36 [169/250 (68%)]
# Train Epoch: 36 [179/250 (72%)]
# Train Epoch: 36 [189/250 (76%)]
# Train Epoch: 36 [199/250 (80%)]
# Train Epoch: 36 [209/250 (84%)]
# Train Epoch: 36 [219/250 (88%)]
# Train Epoch: 36 [229/250 (92%)]
# Train Epoch: 36 [239/250 (96%)]
# Train Epoch: 36 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 37 [9/250 (4%)]
# Train Epoch: 37 [19/250 (8%)]
# Train Epoch: 37 [29/250 (12%)]
# Train Epoch: 37 [39/250 (16%)]
# Train Epoch: 37 [49/250 (20%)]
# Train Epoch: 37 [59/250 (24%)]
# Train Epoch: 37 [69/250 (28%)]
# Train Epoch: 37 [79/250 (32%)]
# Train Epoch: 37 [89/250 (36%)]
# Train Epoch: 37 [99/250 (40%)]
# Train Epoch: 37 [109/250 (44%)]
# Train Epoch: 37 [119/250 (48%)]
# Train Epoch: 37 [129/250 (52%)]
# Train Epoch: 37 [139/250 (56%)]
# Train Epoch: 37 [149/250 (60%)]
# Train Epoch: 37 [159/250 (64%)]
# Train Epoch: 37 [169/250 (68%)]
# Train Epoch: 37 [179/250 (72%)]
# Train Epoch: 37 [189/250 (76%)]
# Train Epoch: 37 [199/250 (80%)]
# Train Epoch: 37 [209/250 (84%)]
# Train Epoch: 37 [219/250 (88%)]
# Train Epoch: 37 [229/250 (92%)]
# Train Epoch: 37 [239/250 (96%)]
# Train Epoch: 37 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 38 [9/250 (4%)]
# Train Epoch: 38 [19/250 (8%)]
# Train Epoch: 38 [29/250 (12%)]
# Train Epoch: 38 [39/250 (16%)]
# Train Epoch: 38 [49/250 (20%)]
# Train Epoch: 38 [59/250 (24%)]
# Train Epoch: 38 [69/250 (28%)]
# Train Epoch: 38 [79/250 (32%)]
# Train Epoch: 38 [89/250 (36%)]
# Train Epoch: 38 [99/250 (40%)]
# Train Epoch: 38 [109/250 (44%)]
# Train Epoch: 38 [119/250 (48%)]
# Train Epoch: 38 [129/250 (52%)]
# Train Epoch: 38 [139/250 (56%)]
# Train Epoch: 38 [149/250 (60%)]
# Train Epoch: 38 [159/250 (64%)]
# Train Epoch: 38 [169/250 (68%)]
# Train Epoch: 38 [179/250 (72%)]
# Train Epoch: 38 [189/250 (76%)]
# Train Epoch: 38 [199/250 (80%)]
# Train Epoch: 38 [209/250 (84%)]
# Train Epoch: 38 [219/250 (88%)]
# Train Epoch: 38 [229/250 (92%)]
# Train Epoch: 38 [239/250 (96%)]
# Train Epoch: 38 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 39 [9/250 (4%)]
# Train Epoch: 39 [19/250 (8%)]
# Train Epoch: 39 [29/250 (12%)]
# Train Epoch: 39 [39/250 (16%)]
# Train Epoch: 39 [49/250 (20%)]
# Train Epoch: 39 [59/250 (24%)]
# Train Epoch: 39 [69/250 (28%)]
# Train Epoch: 39 [79/250 (32%)]
# Train Epoch: 39 [89/250 (36%)]
# Train Epoch: 39 [99/250 (40%)]
# Train Epoch: 39 [109/250 (44%)]
# Train Epoch: 39 [119/250 (48%)]
# Train Epoch: 39 [129/250 (52%)]
# Train Epoch: 39 [139/250 (56%)]
# Train Epoch: 39 [149/250 (60%)]
# Train Epoch: 39 [159/250 (64%)]
# Train Epoch: 39 [169/250 (68%)]
# Train Epoch: 39 [179/250 (72%)]
# Train Epoch: 39 [189/250 (76%)]
# Train Epoch: 39 [199/250 (80%)]
# Train Epoch: 39 [209/250 (84%)]
# Train Epoch: 39 [219/250 (88%)]
# Train Epoch: 39 [229/250 (92%)]
# Train Epoch: 39 [239/250 (96%)]
# Train Epoch: 39 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 40 [9/250 (4%)]
# Train Epoch: 40 [19/250 (8%)]
# Train Epoch: 40 [29/250 (12%)]
# Train Epoch: 40 [39/250 (16%)]
# Train Epoch: 40 [49/250 (20%)]
# Train Epoch: 40 [59/250 (24%)]
# Train Epoch: 40 [69/250 (28%)]
# Train Epoch: 40 [79/250 (32%)]
# Train Epoch: 40 [89/250 (36%)]
# Train Epoch: 40 [99/250 (40%)]
# Train Epoch: 40 [109/250 (44%)]
# Train Epoch: 40 [119/250 (48%)]
# Train Epoch: 40 [129/250 (52%)]
# Train Epoch: 40 [139/250 (56%)]
# Train Epoch: 40 [149/250 (60%)]
# Train Epoch: 40 [159/250 (64%)]
# Train Epoch: 40 [169/250 (68%)]
# Train Epoch: 40 [179/250 (72%)]
# Train Epoch: 40 [189/250 (76%)]
# Train Epoch: 40 [199/250 (80%)]
# Train Epoch: 40 [209/250 (84%)]
# Train Epoch: 40 [219/250 (88%)]
# Train Epoch: 40 [229/250 (92%)]
# Train Epoch: 40 [239/250 (96%)]
# Train Epoch: 40 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 41 [9/250 (4%)]
# Train Epoch: 41 [19/250 (8%)]
# Train Epoch: 41 [29/250 (12%)]
# Train Epoch: 41 [39/250 (16%)]
# Train Epoch: 41 [49/250 (20%)]
# Train Epoch: 41 [59/250 (24%)]
# Train Epoch: 41 [69/250 (28%)]
# Train Epoch: 41 [79/250 (32%)]
# Train Epoch: 41 [89/250 (36%)]
# Train Epoch: 41 [99/250 (40%)]
# Train Epoch: 41 [109/250 (44%)]
# Train Epoch: 41 [119/250 (48%)]
# Train Epoch: 41 [129/250 (52%)]
# Train Epoch: 41 [139/250 (56%)]
# Train Epoch: 41 [149/250 (60%)]
# Train Epoch: 41 [159/250 (64%)]
# Train Epoch: 41 [169/250 (68%)]
# Train Epoch: 41 [179/250 (72%)]
# Train Epoch: 41 [189/250 (76%)]
# Train Epoch: 41 [199/250 (80%)]
# Train Epoch: 41 [209/250 (84%)]
# Train Epoch: 41 [219/250 (88%)]
# Train Epoch: 41 [229/250 (92%)]
# Train Epoch: 41 [239/250 (96%)]
# Train Epoch: 41 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 42 [9/250 (4%)]
# Train Epoch: 42 [19/250 (8%)]
# Train Epoch: 42 [29/250 (12%)]
# Train Epoch: 42 [39/250 (16%)]
# Train Epoch: 42 [49/250 (20%)]
# Train Epoch: 42 [59/250 (24%)]
# Train Epoch: 42 [69/250 (28%)]
# Train Epoch: 42 [79/250 (32%)]
# Train Epoch: 42 [89/250 (36%)]
# Train Epoch: 42 [99/250 (40%)]
# Train Epoch: 42 [109/250 (44%)]
# Train Epoch: 42 [119/250 (48%)]
# Train Epoch: 42 [129/250 (52%)]
# Train Epoch: 42 [139/250 (56%)]
# Train Epoch: 42 [149/250 (60%)]
# Train Epoch: 42 [159/250 (64%)]
# Train Epoch: 42 [169/250 (68%)]
# Train Epoch: 42 [179/250 (72%)]
# Train Epoch: 42 [189/250 (76%)]
# Train Epoch: 42 [199/250 (80%)]
# Train Epoch: 42 [209/250 (84%)]
# Train Epoch: 42 [219/250 (88%)]
# Train Epoch: 42 [229/250 (92%)]
# Train Epoch: 42 [239/250 (96%)]
# Train Epoch: 42 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 43 [9/250 (4%)]
# Train Epoch: 43 [19/250 (8%)]
# Train Epoch: 43 [29/250 (12%)]
# Train Epoch: 43 [39/250 (16%)]
# Train Epoch: 43 [49/250 (20%)]
# Train Epoch: 43 [59/250 (24%)]
# Train Epoch: 43 [69/250 (28%)]
# Train Epoch: 43 [79/250 (32%)]
# Train Epoch: 43 [89/250 (36%)]
# Train Epoch: 43 [99/250 (40%)]
# Train Epoch: 43 [109/250 (44%)]
# Train Epoch: 43 [119/250 (48%)]
# Train Epoch: 43 [129/250 (52%)]
# Train Epoch: 43 [139/250 (56%)]
# Train Epoch: 43 [149/250 (60%)]
# Train Epoch: 43 [159/250 (64%)]
# Train Epoch: 43 [169/250 (68%)]
# Train Epoch: 43 [179/250 (72%)]
# Train Epoch: 43 [189/250 (76%)]
# Train Epoch: 43 [199/250 (80%)]
# Train Epoch: 43 [209/250 (84%)]
# Train Epoch: 43 [219/250 (88%)]
# Train Epoch: 43 [229/250 (92%)]
# Train Epoch: 43 [239/250 (96%)]
# Train Epoch: 43 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 44 [9/250 (4%)]
# Train Epoch: 44 [19/250 (8%)]
# Train Epoch: 44 [29/250 (12%)]
# Train Epoch: 44 [39/250 (16%)]
# Train Epoch: 44 [49/250 (20%)]
# Train Epoch: 44 [59/250 (24%)]
# Train Epoch: 44 [69/250 (28%)]
# Train Epoch: 44 [79/250 (32%)]
# Train Epoch: 44 [89/250 (36%)]
# Train Epoch: 44 [99/250 (40%)]
# Train Epoch: 44 [109/250 (44%)]
# Train Epoch: 44 [119/250 (48%)]
# Train Epoch: 44 [129/250 (52%)]
# Train Epoch: 44 [139/250 (56%)]
# Train Epoch: 44 [149/250 (60%)]
# Train Epoch: 44 [159/250 (64%)]
# Train Epoch: 44 [169/250 (68%)]
# Train Epoch: 44 [179/250 (72%)]
# Train Epoch: 44 [189/250 (76%)]
# Train Epoch: 44 [199/250 (80%)]
# Train Epoch: 44 [209/250 (84%)]
# Train Epoch: 44 [219/250 (88%)]
# Train Epoch: 44 [229/250 (92%)]
# Train Epoch: 44 [239/250 (96%)]
# Train Epoch: 44 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 45 [9/250 (4%)]
# Train Epoch: 45 [19/250 (8%)]
# Train Epoch: 45 [29/250 (12%)]
# Train Epoch: 45 [39/250 (16%)]
# Train Epoch: 45 [49/250 (20%)]
# Train Epoch: 45 [59/250 (24%)]
# Train Epoch: 45 [69/250 (28%)]
# Train Epoch: 45 [79/250 (32%)]
# Train Epoch: 45 [89/250 (36%)]
# Train Epoch: 45 [99/250 (40%)]
# Train Epoch: 45 [109/250 (44%)]
# Train Epoch: 45 [119/250 (48%)]
# Train Epoch: 45 [129/250 (52%)]
# Train Epoch: 45 [139/250 (56%)]
# Train Epoch: 45 [149/250 (60%)]
# Train Epoch: 45 [159/250 (64%)]
# Train Epoch: 45 [169/250 (68%)]
# Train Epoch: 45 [179/250 (72%)]
# Train Epoch: 45 [189/250 (76%)]
# Train Epoch: 45 [199/250 (80%)]
# Train Epoch: 45 [209/250 (84%)]
# Train Epoch: 45 [219/250 (88%)]
# Train Epoch: 45 [229/250 (92%)]
# Train Epoch: 45 [239/250 (96%)]
# Train Epoch: 45 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 46 [9/250 (4%)]
# Train Epoch: 46 [19/250 (8%)]
# Train Epoch: 46 [29/250 (12%)]
# Train Epoch: 46 [39/250 (16%)]
# Train Epoch: 46 [49/250 (20%)]
# Train Epoch: 46 [59/250 (24%)]
# Train Epoch: 46 [69/250 (28%)]
# Train Epoch: 46 [79/250 (32%)]
# Train Epoch: 46 [89/250 (36%)]
# Train Epoch: 46 [99/250 (40%)]
# Train Epoch: 46 [109/250 (44%)]
# Train Epoch: 46 [119/250 (48%)]
# Train Epoch: 46 [129/250 (52%)]
# Train Epoch: 46 [139/250 (56%)]
# Train Epoch: 46 [149/250 (60%)]
# Train Epoch: 46 [159/250 (64%)]
# Train Epoch: 46 [169/250 (68%)]
# Train Epoch: 46 [179/250 (72%)]
# Train Epoch: 46 [189/250 (76%)]
# Train Epoch: 46 [199/250 (80%)]
# Train Epoch: 46 [209/250 (84%)]
# Train Epoch: 46 [219/250 (88%)]
# Train Epoch: 46 [229/250 (92%)]
# Train Epoch: 46 [239/250 (96%)]
# Train Epoch: 46 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 47 [9/250 (4%)]
# Train Epoch: 47 [19/250 (8%)]
# Train Epoch: 47 [29/250 (12%)]
# Train Epoch: 47 [39/250 (16%)]
# Train Epoch: 47 [49/250 (20%)]
# Train Epoch: 47 [59/250 (24%)]
# Train Epoch: 47 [69/250 (28%)]
# Train Epoch: 47 [79/250 (32%)]
# Train Epoch: 47 [89/250 (36%)]
# Train Epoch: 47 [99/250 (40%)]
# Train Epoch: 47 [109/250 (44%)]
# Train Epoch: 47 [119/250 (48%)]
# Train Epoch: 47 [129/250 (52%)]
# Train Epoch: 47 [139/250 (56%)]
# Train Epoch: 47 [149/250 (60%)]
# Train Epoch: 47 [159/250 (64%)]
# Train Epoch: 47 [169/250 (68%)]
# Train Epoch: 47 [179/250 (72%)]
# Train Epoch: 47 [189/250 (76%)]
# Train Epoch: 47 [199/250 (80%)]
# Train Epoch: 47 [209/250 (84%)]
# Train Epoch: 47 [219/250 (88%)]
# Train Epoch: 47 [229/250 (92%)]
# Train Epoch: 47 [239/250 (96%)]
# Train Epoch: 47 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 48 [9/250 (4%)]
# Train Epoch: 48 [19/250 (8%)]
# Train Epoch: 48 [29/250 (12%)]
# Train Epoch: 48 [39/250 (16%)]
# Train Epoch: 48 [49/250 (20%)]
# Train Epoch: 48 [59/250 (24%)]
# Train Epoch: 48 [69/250 (28%)]
# Train Epoch: 48 [79/250 (32%)]
# Train Epoch: 48 [89/250 (36%)]
# Train Epoch: 48 [99/250 (40%)]
# Train Epoch: 48 [109/250 (44%)]
# Train Epoch: 48 [119/250 (48%)]
# Train Epoch: 48 [129/250 (52%)]
# Train Epoch: 48 [139/250 (56%)]
# Train Epoch: 48 [149/250 (60%)]
# Train Epoch: 48 [159/250 (64%)]
# Train Epoch: 48 [169/250 (68%)]
# Train Epoch: 48 [179/250 (72%)]
# Train Epoch: 48 [189/250 (76%)]
# Train Epoch: 48 [199/250 (80%)]
# Train Epoch: 48 [209/250 (84%)]
# Train Epoch: 48 [219/250 (88%)]
# Train Epoch: 48 [229/250 (92%)]
# Train Epoch: 48 [239/250 (96%)]
# Train Epoch: 48 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 49 [9/250 (4%)]
# Train Epoch: 49 [19/250 (8%)]
# Train Epoch: 49 [29/250 (12%)]
# Train Epoch: 49 [39/250 (16%)]
# Train Epoch: 49 [49/250 (20%)]
# Train Epoch: 49 [59/250 (24%)]
# Train Epoch: 49 [69/250 (28%)]
# Train Epoch: 49 [79/250 (32%)]
# Train Epoch: 49 [89/250 (36%)]
# Train Epoch: 49 [99/250 (40%)]
# Train Epoch: 49 [109/250 (44%)]
# Train Epoch: 49 [119/250 (48%)]
# Train Epoch: 49 [129/250 (52%)]
# Train Epoch: 49 [139/250 (56%)]
# Train Epoch: 49 [149/250 (60%)]
# Train Epoch: 49 [159/250 (64%)]
# Train Epoch: 49 [169/250 (68%)]
# Train Epoch: 49 [179/250 (72%)]
# Train Epoch: 49 [189/250 (76%)]
# Train Epoch: 49 [199/250 (80%)]
# Train Epoch: 49 [209/250 (84%)]
# Train Epoch: 49 [219/250 (88%)]
# Train Epoch: 49 [229/250 (92%)]
# Train Epoch: 49 [239/250 (96%)]
# Train Epoch: 49 [249/250 (100%)]
# Data set: Average loss: 0.0000
# Train Epoch: 50 [9/250 (4%)]
# Train Epoch: 50 [19/250 (8%)]
# Train Epoch: 50 [29/250 (12%)]
# Train Epoch: 50 [39/250 (16%)]
# Train Epoch: 50 [49/250 (20%)]
# Train Epoch: 50 [59/250 (24%)]
# Train Epoch: 50 [69/250 (28%)]
# Train Epoch: 50 [79/250 (32%)]
# Train Epoch: 50 [89/250 (36%)]
# Train Epoch: 50 [99/250 (40%)]
# Train Epoch: 50 [109/250 (44%)]
# Train Epoch: 50 [119/250 (48%)]
# Train Epoch: 50 [129/250 (52%)]
# Train Epoch: 50 [139/250 (56%)]
# Train Epoch: 50 [149/250 (60%)]
# Train Epoch: 50 [159/250 (64%)]
# Train Epoch: 50 [169/250 (68%)]
# Train Epoch: 50 [179/250 (72%)]
# Train Epoch: 50 [189/250 (76%)]
# Train Epoch: 50 [199/250 (80%)]
# Train Epoch: 50 [209/250 (84%)]
# Train Epoch: 50 [219/250 (88%)]
# Train Epoch: 50 [229/250 (92%)]
# Train Epoch: 50 [239/250 (96%)]
# Train Epoch: 50 [249/250 (100%)]
# Data set: Average loss: 0.0000

# %%
plt.plot(range(train_epochs_start, train_epochs_end), avg_losses)
plt.xlabel('Epoch')
plt.ylabel('Average loss')
plt.savefig('ssl1_loss.png')
plt.show()

# %%
plot_change(model.cpu(), model_old)

# %%
model = model.cpu()
fig, axes = plt.subplots(3, 4)
for i in range(3):
    samples = dataset[i * 200] # so that the images are different
    image0, label0 = samples['img0'], samples['label0']
    image1, label1 = samples['img1'], samples['label1']
    image2, label2 = samples['img2'], samples['label2']
    image3, label3 = samples['img3'], samples['label3']
    gradcam(model, image0, detransformer, label0, axes[i][0])
    gradcam(model, image1, detransformer, label1, axes[i][1])
    gradcam(model, image2, detransformer, label2, axes[i][2])
    gradcam(model, image3, detransformer, label3, axes[i][3])

fig.savefig('ssl1_gradcam.png')
fig.show()

# %%
torch.save(model.state_dict(), 'ssl1.pt')

# %% [markdown]
# # SSL on COVID-CT

# %%
os.mkdir('ssl2_backup')
os.mkdir('ssl2_result')

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)
np.random.seed(42)
torch.backends.cudnn.deterministic = True
rng = np.random.RandomState(42)

# %%
torch.cuda.empty_cache()

device = 'cuda'
batchsize = 4
train_epochs_start = 0
train_epochs_end = 50
ssl1_epochs = 50

# %%
model = RotNet()
modelname = 'RotNet'

if train_epochs_start > 0:
    model.load_state_dict(
        torch.load('ssl2_backup/{}_{}.pt'.format(
            modelname,
            train_epochs_start
        ))
    )
else:
    model.load_state_dict(
        torch.load('ssl1_backup/{}_{}.pt'.format(
            modelname,
            ssl1_epochs
        ))
    )

if device == 'cuda':
    model = model.cuda()

# %%
model_old = RotNet()
model_old.load_state_dict(model.state_dict())
# Out:
# <All keys matched successfully>

# %%
normalize = transforms.Normalize(
    mean=[0.45271412, 0.45271412, 0.45271412],
    std=[0.33165374, 0.33165374, 0.33165374]
)
transformer = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    normalize
])

detransformer = torchvision.transforms.Compose([
    lambda image_tensor : image_tensor * torch.tensor([0.33165374, 0.33165374, 0.33165374])[:, None, None],
    lambda image_tensor : image_tensor + torch.tensor([0.45271412, 0.45271412, 0.45271412])[:, None, None],
    torchvision.transforms.ToPILImage()
])

# %%
class CovidCTDataset(Dataset):
    def __init__(self, root_dir, txt_COVID, txt_NonCOVID, transform=transformer):
        """
            Args:
                txt_path (string): Path to the txt file with annotations.
                root_dir (string): Directory with all the images.
                transform (callable, optional): Optional transform to be applied on a sample.
            File structure:
                - root_dir
                    - CT_COVID
                        - img1.png
                        - img2.png
                        - ......
                    - CT_NonCOVID
                        - img1.png
                        - img2.png
                        - ......
        """
        self.root_dir = root_dir
        self.txt_path = [txt_COVID, txt_NonCOVID]
        self.classes = ['CT_COVID', 'CT_NonCOVID']
        self.num_cls = len(self.classes)
        self.img_list = []
        for c in range(self.num_cls):
            cls_list = [os.path.join(self.root_dir, self.classes[c], item) for item in read_txt(self.txt_path[c])]
            self.img_list += cls_list
        self.transform = transform

    def __len__(self):
        return len(self.img_list)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_path = self.img_list[idx]
        image = Image.open(img_path).convert('RGB')

        image = self.transform(image)
        image0 = rotate(image, 0)
        image1 = rotate(image, 90)
        image2 = rotate(image, 180)
        image3 = rotate(image, 270)

        sample = {
            'img0': image0, 'label0': 0,
            'img1': image1, 'label1': 1,
            'img2': image2, 'label2': 2,
            'img3': image3, 'label3': 3
        }
        return sample

# %%
dataset = CovidCTDataset(
    root_dir='Images',
    txt_COVID='Data-split/COVID/trainCT_COVID.txt',
    txt_NonCOVID='Data-split/NonCOVID/trainCT_NonCOVID.txt',
    transform=transformer
)
print("dataset length:", dataset.__len__())
data_loader = DataLoader(dataset, batch_size=batchsize, drop_last=False, shuffle=True)
# Out:
# dataset length: 425

# %%
def train(epoch):

    model.train()

    train_loss = 0

    for batch_index, batch_samples in enumerate(data_loader):

        # move data to device
        data0, label0 = batch_samples['img0'].to(device), batch_samples['label0'].to(device)
        data1, label1 = batch_samples['img1'].to(device), batch_samples['label1'].to(device)
        data2, label2 = batch_samples['img2'].to(device), batch_samples['label2'].to(device)
        data3, label3 = batch_samples['img3'].to(device), batch_samples['label3'].to(device)

        output0 = model(data0)
        output1 = model(data1)
        output2 = model(data2)
        output3 = model(data3)

        loss0 = criteria(output0, label0.long())
        loss1 = criteria(output1, label1.long())
        loss2 = criteria(output2, label2.long())
        loss3 = criteria(output3, label3.long())
        loss = (loss0 + loss1 + loss2 + loss3) / 4.
        train_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Display progress
        if (batch_index + 1) % bs == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]'.format(
                epoch,
                batch_index, len(data_loader),
                100.0 * batch_index / len(data_loader)
            ))

    avg_loss = train_loss / len(data_loader.dataset)
    print('Data set: Average loss: {:.4f}'.format(avg_loss))
    f = open('ssl2_result/train_{}.txt'.format(modelname), 'a+')
    f.write('Data set: Average loss: {:.4f}'.format(avg_loss))
    f.close()
    avg_losses.append(avg_loss)

# %%
bs = 10
T_checkpoint = 10
avg_losses = []

criteria = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

for epoch in range(train_epochs_start + 1, train_epochs_end + 1):
    train(epoch)
    
    if epoch % T_checkpoint == 0:
        # checkpoint
        torch.save(model.state_dict(), 'ssl2_backup/{}_{}.pt'.format(modelname, epoch))
# Out:
# Train Epoch: 1 [9/107 (8%)]
# Train Epoch: 1 [19/107 (18%)]
# Train Epoch: 1 [29/107 (27%)]
# Train Epoch: 1 [39/107 (36%)]
# Train Epoch: 1 [49/107 (46%)]
# Train Epoch: 1 [59/107 (55%)]
# Train Epoch: 1 [69/107 (64%)]
# Train Epoch: 1 [79/107 (74%)]
# Train Epoch: 1 [89/107 (83%)]
# Train Epoch: 1 [99/107 (93%)]
# Data set: Average loss: 0.1674
# Train Epoch: 2 [9/107 (8%)]
# Train Epoch: 2 [19/107 (18%)]
# Train Epoch: 2 [29/107 (27%)]
# Train Epoch: 2 [39/107 (36%)]
# Train Epoch: 2 [49/107 (46%)]
# Train Epoch: 2 [59/107 (55%)]
# Train Epoch: 2 [69/107 (64%)]
# Train Epoch: 2 [79/107 (74%)]
# Train Epoch: 2 [89/107 (83%)]
# Train Epoch: 2 [99/107 (93%)]
# Data set: Average loss: 0.0097
# Train Epoch: 3 [9/107 (8%)]
# Train Epoch: 3 [19/107 (18%)]
# Train Epoch: 3 [29/107 (27%)]
# Train Epoch: 3 [39/107 (36%)]
# Train Epoch: 3 [49/107 (46%)]
# Train Epoch: 3 [59/107 (55%)]
# Train Epoch: 3 [69/107 (64%)]
# Train Epoch: 3 [79/107 (74%)]
# Train Epoch: 3 [89/107 (83%)]
# Train Epoch: 3 [99/107 (93%)]
# Data set: Average loss: 0.0002
# Train Epoch: 4 [9/107 (8%)]
# Train Epoch: 4 [19/107 (18%)]
# Train Epoch: 4 [29/107 (27%)]
# Train Epoch: 4 [39/107 (36%)]
# Train Epoch: 4 [49/107 (46%)]
# Train Epoch: 4 [59/107 (55%)]
# Train Epoch: 4 [69/107 (64%)]
# Train Epoch: 4 [79/107 (74%)]
# Train Epoch: 4 [89/107 (83%)]
# Train Epoch: 4 [99/107 (93%)]
# Data set: Average loss: 0.0001
# Train Epoch: 5 [9/107 (8%)]
# Train Epoch: 5 [19/107 (18%)]
# Train Epoch: 5 [29/107 (27%)]
# Train Epoch: 5 [39/107 (36%)]
# Train Epoch: 5 [49/107 (46%)]
# Train Epoch: 5 [59/107 (55%)]
# Train Epoch: 5 [69/107 (64%)]
# Train Epoch: 5 [79/107 (74%)]
# Train Epoch: 5 [89/107 (83%)]
# Train Epoch: 5 [99/107 (93%)]
# Data set: Average loss: 0.0001
# Train Epoch: 6 [9/107 (8%)]
# Train Epoch: 6 [19/107 (18%)]
# Train Epoch: 6 [29/107 (27%)]
# Train Epoch: 6 [39/107 (36%)]
# Train Epoch: 6 [49/107 (46%)]
# Train Epoch: 6 [59/107 (55%)]
# Train Epoch: 6 [69/107 (64%)]
# Train Epoch: 6 [79/107 (74%)]
# Train Epoch: 6 [89/107 (83%)]
# Train Epoch: 6 [99/107 (93%)]
# Data set: Average loss: 0.0001
# Train Epoch: 7 [9/107 (8%)]
# Train Epoch: 7 [19/107 (18%)]
# Train Epoch: 7 [29/107 (27%)]
# Train Epoch: 7 [39/107 (36%)]
# Train Epoch: 7 [49/107 (46%)]
# Train Epoch: 7 [59/107 (55%)]
# Train Epoch: 7 [69/107 (64%)]
# Train Epoch: 7 [79/107 (74%)]
# Train Epoch: 7 [89/107 (83%)]
# Train Epoch: 7 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 8 [9/107 (8%)]
# Train Epoch: 8 [19/107 (18%)]
# Train Epoch: 8 [29/107 (27%)]
# Train Epoch: 8 [39/107 (36%)]
# Train Epoch: 8 [49/107 (46%)]
# Train Epoch: 8 [59/107 (55%)]
# Train Epoch: 8 [69/107 (64%)]
# Train Epoch: 8 [79/107 (74%)]
# Train Epoch: 8 [89/107 (83%)]
# Train Epoch: 8 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 9 [9/107 (8%)]
# Train Epoch: 9 [19/107 (18%)]
# Train Epoch: 9 [29/107 (27%)]
# Train Epoch: 9 [39/107 (36%)]
# Train Epoch: 9 [49/107 (46%)]
# Train Epoch: 9 [59/107 (55%)]
# Train Epoch: 9 [69/107 (64%)]
# Train Epoch: 9 [79/107 (74%)]
# Train Epoch: 9 [89/107 (83%)]
# Train Epoch: 9 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 10 [9/107 (8%)]
# Train Epoch: 10 [19/107 (18%)]
# Train Epoch: 10 [29/107 (27%)]
# Train Epoch: 10 [39/107 (36%)]
# Train Epoch: 10 [49/107 (46%)]
# Train Epoch: 10 [59/107 (55%)]
# Train Epoch: 10 [69/107 (64%)]
# Train Epoch: 10 [79/107 (74%)]
# Train Epoch: 10 [89/107 (83%)]
# Train Epoch: 10 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 11 [9/107 (8%)]
# Train Epoch: 11 [19/107 (18%)]
# Train Epoch: 11 [29/107 (27%)]
# Train Epoch: 11 [39/107 (36%)]
# Train Epoch: 11 [49/107 (46%)]
# Train Epoch: 11 [59/107 (55%)]
# Train Epoch: 11 [69/107 (64%)]
# Train Epoch: 11 [79/107 (74%)]
# Train Epoch: 11 [89/107 (83%)]
# Train Epoch: 11 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 12 [9/107 (8%)]
# Train Epoch: 12 [19/107 (18%)]
# Train Epoch: 12 [29/107 (27%)]
# Train Epoch: 12 [39/107 (36%)]
# Train Epoch: 12 [49/107 (46%)]
# Train Epoch: 12 [59/107 (55%)]
# Train Epoch: 12 [69/107 (64%)]
# Train Epoch: 12 [79/107 (74%)]
# Train Epoch: 12 [89/107 (83%)]
# Train Epoch: 12 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 13 [9/107 (8%)]
# Train Epoch: 13 [19/107 (18%)]
# Train Epoch: 13 [29/107 (27%)]
# Train Epoch: 13 [39/107 (36%)]
# Train Epoch: 13 [49/107 (46%)]
# Train Epoch: 13 [59/107 (55%)]
# Train Epoch: 13 [69/107 (64%)]
# Train Epoch: 13 [79/107 (74%)]
# Train Epoch: 13 [89/107 (83%)]
# Train Epoch: 13 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 14 [9/107 (8%)]
# Train Epoch: 14 [19/107 (18%)]
# Train Epoch: 14 [29/107 (27%)]
# Train Epoch: 14 [39/107 (36%)]
# Train Epoch: 14 [49/107 (46%)]
# Train Epoch: 14 [59/107 (55%)]
# Train Epoch: 14 [69/107 (64%)]
# Train Epoch: 14 [79/107 (74%)]
# Train Epoch: 14 [89/107 (83%)]
# Train Epoch: 14 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 15 [9/107 (8%)]
# Train Epoch: 15 [19/107 (18%)]
# Train Epoch: 15 [29/107 (27%)]
# Train Epoch: 15 [39/107 (36%)]
# Train Epoch: 15 [49/107 (46%)]
# Train Epoch: 15 [59/107 (55%)]
# Train Epoch: 15 [69/107 (64%)]
# Train Epoch: 15 [79/107 (74%)]
# Train Epoch: 15 [89/107 (83%)]
# Train Epoch: 15 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 16 [9/107 (8%)]
# Train Epoch: 16 [19/107 (18%)]
# Train Epoch: 16 [29/107 (27%)]
# Train Epoch: 16 [39/107 (36%)]
# Train Epoch: 16 [49/107 (46%)]
# Train Epoch: 16 [59/107 (55%)]
# Train Epoch: 16 [69/107 (64%)]
# Train Epoch: 16 [79/107 (74%)]
# Train Epoch: 16 [89/107 (83%)]
# Train Epoch: 16 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 17 [9/107 (8%)]
# Train Epoch: 17 [19/107 (18%)]
# Train Epoch: 17 [29/107 (27%)]
# Train Epoch: 17 [39/107 (36%)]
# Train Epoch: 17 [49/107 (46%)]
# Train Epoch: 17 [59/107 (55%)]
# Train Epoch: 17 [69/107 (64%)]
# Train Epoch: 17 [79/107 (74%)]
# Train Epoch: 17 [89/107 (83%)]
# Train Epoch: 17 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 18 [9/107 (8%)]
# Train Epoch: 18 [19/107 (18%)]
# Train Epoch: 18 [29/107 (27%)]
# Train Epoch: 18 [39/107 (36%)]
# Train Epoch: 18 [49/107 (46%)]
# Train Epoch: 18 [59/107 (55%)]
# Train Epoch: 18 [69/107 (64%)]
# Train Epoch: 18 [79/107 (74%)]
# Train Epoch: 18 [89/107 (83%)]
# Train Epoch: 18 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 19 [9/107 (8%)]
# Train Epoch: 19 [19/107 (18%)]
# Train Epoch: 19 [29/107 (27%)]
# Train Epoch: 19 [39/107 (36%)]
# Train Epoch: 19 [49/107 (46%)]
# Train Epoch: 19 [59/107 (55%)]
# Train Epoch: 19 [69/107 (64%)]
# Train Epoch: 19 [79/107 (74%)]
# Train Epoch: 19 [89/107 (83%)]
# Train Epoch: 19 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 20 [9/107 (8%)]
# Train Epoch: 20 [19/107 (18%)]
# Train Epoch: 20 [29/107 (27%)]
# Train Epoch: 20 [39/107 (36%)]
# Train Epoch: 20 [49/107 (46%)]
# Train Epoch: 20 [59/107 (55%)]
# Train Epoch: 20 [69/107 (64%)]
# Train Epoch: 20 [79/107 (74%)]
# Train Epoch: 20 [89/107 (83%)]
# Train Epoch: 20 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 21 [9/107 (8%)]
# Train Epoch: 21 [19/107 (18%)]
# Train Epoch: 21 [29/107 (27%)]
# Train Epoch: 21 [39/107 (36%)]
# Train Epoch: 21 [49/107 (46%)]
# Train Epoch: 21 [59/107 (55%)]
# Train Epoch: 21 [69/107 (64%)]
# Train Epoch: 21 [79/107 (74%)]
# Train Epoch: 21 [89/107 (83%)]
# Train Epoch: 21 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 22 [9/107 (8%)]
# Train Epoch: 22 [19/107 (18%)]
# Train Epoch: 22 [29/107 (27%)]
# Train Epoch: 22 [39/107 (36%)]
# Train Epoch: 22 [49/107 (46%)]
# Train Epoch: 22 [59/107 (55%)]
# Train Epoch: 22 [69/107 (64%)]
# Train Epoch: 22 [79/107 (74%)]
# Train Epoch: 22 [89/107 (83%)]
# Train Epoch: 22 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 23 [9/107 (8%)]
# Train Epoch: 23 [19/107 (18%)]
# Train Epoch: 23 [29/107 (27%)]
# Train Epoch: 23 [39/107 (36%)]
# Train Epoch: 23 [49/107 (46%)]
# Train Epoch: 23 [59/107 (55%)]
# Train Epoch: 23 [69/107 (64%)]
# Train Epoch: 23 [79/107 (74%)]
# Train Epoch: 23 [89/107 (83%)]
# Train Epoch: 23 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 24 [9/107 (8%)]
# Train Epoch: 24 [19/107 (18%)]
# Train Epoch: 24 [29/107 (27%)]
# Train Epoch: 24 [39/107 (36%)]
# Train Epoch: 24 [49/107 (46%)]
# Train Epoch: 24 [59/107 (55%)]
# Train Epoch: 24 [69/107 (64%)]
# Train Epoch: 24 [79/107 (74%)]
# Train Epoch: 24 [89/107 (83%)]
# Train Epoch: 24 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 25 [9/107 (8%)]
# Train Epoch: 25 [19/107 (18%)]
# Train Epoch: 25 [29/107 (27%)]
# Train Epoch: 25 [39/107 (36%)]
# Train Epoch: 25 [49/107 (46%)]
# Train Epoch: 25 [59/107 (55%)]
# Train Epoch: 25 [69/107 (64%)]
# Train Epoch: 25 [79/107 (74%)]
# Train Epoch: 25 [89/107 (83%)]
# Train Epoch: 25 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 26 [9/107 (8%)]
# Train Epoch: 26 [19/107 (18%)]
# Train Epoch: 26 [29/107 (27%)]
# Train Epoch: 26 [39/107 (36%)]
# Train Epoch: 26 [49/107 (46%)]
# Train Epoch: 26 [59/107 (55%)]
# Train Epoch: 26 [69/107 (64%)]
# Train Epoch: 26 [79/107 (74%)]
# Train Epoch: 26 [89/107 (83%)]
# Train Epoch: 26 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 27 [9/107 (8%)]
# Train Epoch: 27 [19/107 (18%)]
# Train Epoch: 27 [29/107 (27%)]
# Train Epoch: 27 [39/107 (36%)]
# Train Epoch: 27 [49/107 (46%)]
# Train Epoch: 27 [59/107 (55%)]
# Train Epoch: 27 [69/107 (64%)]
# Train Epoch: 27 [79/107 (74%)]
# Train Epoch: 27 [89/107 (83%)]
# Train Epoch: 27 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 28 [9/107 (8%)]
# Train Epoch: 28 [19/107 (18%)]
# Train Epoch: 28 [29/107 (27%)]
# Train Epoch: 28 [39/107 (36%)]
# Train Epoch: 28 [49/107 (46%)]
# Train Epoch: 28 [59/107 (55%)]
# Train Epoch: 28 [69/107 (64%)]
# Train Epoch: 28 [79/107 (74%)]
# Train Epoch: 28 [89/107 (83%)]
# Train Epoch: 28 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 29 [9/107 (8%)]
# Train Epoch: 29 [19/107 (18%)]
# Train Epoch: 29 [29/107 (27%)]
# Train Epoch: 29 [39/107 (36%)]
# Train Epoch: 29 [49/107 (46%)]
# Train Epoch: 29 [59/107 (55%)]
# Train Epoch: 29 [69/107 (64%)]
# Train Epoch: 29 [79/107 (74%)]
# Train Epoch: 29 [89/107 (83%)]
# Train Epoch: 29 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 30 [9/107 (8%)]
# Train Epoch: 30 [19/107 (18%)]
# Train Epoch: 30 [29/107 (27%)]
# Train Epoch: 30 [39/107 (36%)]
# Train Epoch: 30 [49/107 (46%)]
# Train Epoch: 30 [59/107 (55%)]
# Train Epoch: 30 [69/107 (64%)]
# Train Epoch: 30 [79/107 (74%)]
# Train Epoch: 30 [89/107 (83%)]
# Train Epoch: 30 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 31 [9/107 (8%)]
# Train Epoch: 31 [19/107 (18%)]
# Train Epoch: 31 [29/107 (27%)]
# Train Epoch: 31 [39/107 (36%)]
# Train Epoch: 31 [49/107 (46%)]
# Train Epoch: 31 [59/107 (55%)]
# Train Epoch: 31 [69/107 (64%)]
# Train Epoch: 31 [79/107 (74%)]
# Train Epoch: 31 [89/107 (83%)]
# Train Epoch: 31 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 32 [9/107 (8%)]
# Train Epoch: 32 [19/107 (18%)]
# Train Epoch: 32 [29/107 (27%)]
# Train Epoch: 32 [39/107 (36%)]
# Train Epoch: 32 [49/107 (46%)]
# Train Epoch: 32 [59/107 (55%)]
# Train Epoch: 32 [69/107 (64%)]
# Train Epoch: 32 [79/107 (74%)]
# Train Epoch: 32 [89/107 (83%)]
# Train Epoch: 32 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 33 [9/107 (8%)]
# Train Epoch: 33 [19/107 (18%)]
# Train Epoch: 33 [29/107 (27%)]
# Train Epoch: 33 [39/107 (36%)]
# Train Epoch: 33 [49/107 (46%)]
# Train Epoch: 33 [59/107 (55%)]
# Train Epoch: 33 [69/107 (64%)]
# Train Epoch: 33 [79/107 (74%)]
# Train Epoch: 33 [89/107 (83%)]
# Train Epoch: 33 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 34 [9/107 (8%)]
# Train Epoch: 34 [19/107 (18%)]
# Train Epoch: 34 [29/107 (27%)]
# Train Epoch: 34 [39/107 (36%)]
# Train Epoch: 34 [49/107 (46%)]
# Train Epoch: 34 [59/107 (55%)]
# Train Epoch: 34 [69/107 (64%)]
# Train Epoch: 34 [79/107 (74%)]
# Train Epoch: 34 [89/107 (83%)]
# Train Epoch: 34 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 35 [9/107 (8%)]
# Train Epoch: 35 [19/107 (18%)]
# Train Epoch: 35 [29/107 (27%)]
# Train Epoch: 35 [39/107 (36%)]
# Train Epoch: 35 [49/107 (46%)]
# Train Epoch: 35 [59/107 (55%)]
# Train Epoch: 35 [69/107 (64%)]
# Train Epoch: 35 [79/107 (74%)]
# Train Epoch: 35 [89/107 (83%)]
# Train Epoch: 35 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 36 [9/107 (8%)]
# Train Epoch: 36 [19/107 (18%)]
# Train Epoch: 36 [29/107 (27%)]
# Train Epoch: 36 [39/107 (36%)]
# Train Epoch: 36 [49/107 (46%)]
# Train Epoch: 36 [59/107 (55%)]
# Train Epoch: 36 [69/107 (64%)]
# Train Epoch: 36 [79/107 (74%)]
# Train Epoch: 36 [89/107 (83%)]
# Train Epoch: 36 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 37 [9/107 (8%)]
# Train Epoch: 37 [19/107 (18%)]
# Train Epoch: 37 [29/107 (27%)]
# Train Epoch: 37 [39/107 (36%)]
# Train Epoch: 37 [49/107 (46%)]
# Train Epoch: 37 [59/107 (55%)]
# Train Epoch: 37 [69/107 (64%)]
# Train Epoch: 37 [79/107 (74%)]
# Train Epoch: 37 [89/107 (83%)]
# Train Epoch: 37 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 38 [9/107 (8%)]
# Train Epoch: 38 [19/107 (18%)]
# Train Epoch: 38 [29/107 (27%)]
# Train Epoch: 38 [39/107 (36%)]
# Train Epoch: 38 [49/107 (46%)]
# Train Epoch: 38 [59/107 (55%)]
# Train Epoch: 38 [69/107 (64%)]
# Train Epoch: 38 [79/107 (74%)]
# Train Epoch: 38 [89/107 (83%)]
# Train Epoch: 38 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 39 [9/107 (8%)]
# Train Epoch: 39 [19/107 (18%)]
# Train Epoch: 39 [29/107 (27%)]
# Train Epoch: 39 [39/107 (36%)]
# Train Epoch: 39 [49/107 (46%)]
# Train Epoch: 39 [59/107 (55%)]
# Train Epoch: 39 [69/107 (64%)]
# Train Epoch: 39 [79/107 (74%)]
# Train Epoch: 39 [89/107 (83%)]
# Train Epoch: 39 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 40 [9/107 (8%)]
# Train Epoch: 40 [19/107 (18%)]
# Train Epoch: 40 [29/107 (27%)]
# Train Epoch: 40 [39/107 (36%)]
# Train Epoch: 40 [49/107 (46%)]
# Train Epoch: 40 [59/107 (55%)]
# Train Epoch: 40 [69/107 (64%)]
# Train Epoch: 40 [79/107 (74%)]
# Train Epoch: 40 [89/107 (83%)]
# Train Epoch: 40 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 41 [9/107 (8%)]
# Train Epoch: 41 [19/107 (18%)]
# Train Epoch: 41 [29/107 (27%)]
# Train Epoch: 41 [39/107 (36%)]
# Train Epoch: 41 [49/107 (46%)]
# Train Epoch: 41 [59/107 (55%)]
# Train Epoch: 41 [69/107 (64%)]
# Train Epoch: 41 [79/107 (74%)]
# Train Epoch: 41 [89/107 (83%)]
# Train Epoch: 41 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 42 [9/107 (8%)]
# Train Epoch: 42 [19/107 (18%)]
# Train Epoch: 42 [29/107 (27%)]
# Train Epoch: 42 [39/107 (36%)]
# Train Epoch: 42 [49/107 (46%)]
# Train Epoch: 42 [59/107 (55%)]
# Train Epoch: 42 [69/107 (64%)]
# Train Epoch: 42 [79/107 (74%)]
# Train Epoch: 42 [89/107 (83%)]
# Train Epoch: 42 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 43 [9/107 (8%)]
# Train Epoch: 43 [19/107 (18%)]
# Train Epoch: 43 [29/107 (27%)]
# Train Epoch: 43 [39/107 (36%)]
# Train Epoch: 43 [49/107 (46%)]
# Train Epoch: 43 [59/107 (55%)]
# Train Epoch: 43 [69/107 (64%)]
# Train Epoch: 43 [79/107 (74%)]
# Train Epoch: 43 [89/107 (83%)]
# Train Epoch: 43 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 44 [9/107 (8%)]
# Train Epoch: 44 [19/107 (18%)]
# Train Epoch: 44 [29/107 (27%)]
# Train Epoch: 44 [39/107 (36%)]
# Train Epoch: 44 [49/107 (46%)]
# Train Epoch: 44 [59/107 (55%)]
# Train Epoch: 44 [69/107 (64%)]
# Train Epoch: 44 [79/107 (74%)]
# Train Epoch: 44 [89/107 (83%)]
# Train Epoch: 44 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 45 [9/107 (8%)]
# Train Epoch: 45 [19/107 (18%)]
# Train Epoch: 45 [29/107 (27%)]
# Train Epoch: 45 [39/107 (36%)]
# Train Epoch: 45 [49/107 (46%)]
# Train Epoch: 45 [59/107 (55%)]
# Train Epoch: 45 [69/107 (64%)]
# Train Epoch: 45 [79/107 (74%)]
# Train Epoch: 45 [89/107 (83%)]
# Train Epoch: 45 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 46 [9/107 (8%)]
# Train Epoch: 46 [19/107 (18%)]
# Train Epoch: 46 [29/107 (27%)]
# Train Epoch: 46 [39/107 (36%)]
# Train Epoch: 46 [49/107 (46%)]
# Train Epoch: 46 [59/107 (55%)]
# Train Epoch: 46 [69/107 (64%)]
# Train Epoch: 46 [79/107 (74%)]
# Train Epoch: 46 [89/107 (83%)]
# Train Epoch: 46 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 47 [9/107 (8%)]
# Train Epoch: 47 [19/107 (18%)]
# Train Epoch: 47 [29/107 (27%)]
# Train Epoch: 47 [39/107 (36%)]
# Train Epoch: 47 [49/107 (46%)]
# Train Epoch: 47 [59/107 (55%)]
# Train Epoch: 47 [69/107 (64%)]
# Train Epoch: 47 [79/107 (74%)]
# Train Epoch: 47 [89/107 (83%)]
# Train Epoch: 47 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 48 [9/107 (8%)]
# Train Epoch: 48 [19/107 (18%)]
# Train Epoch: 48 [29/107 (27%)]
# Train Epoch: 48 [39/107 (36%)]
# Train Epoch: 48 [49/107 (46%)]
# Train Epoch: 48 [59/107 (55%)]
# Train Epoch: 48 [69/107 (64%)]
# Train Epoch: 48 [79/107 (74%)]
# Train Epoch: 48 [89/107 (83%)]
# Train Epoch: 48 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 49 [9/107 (8%)]
# Train Epoch: 49 [19/107 (18%)]
# Train Epoch: 49 [29/107 (27%)]
# Train Epoch: 49 [39/107 (36%)]
# Train Epoch: 49 [49/107 (46%)]
# Train Epoch: 49 [59/107 (55%)]
# Train Epoch: 49 [69/107 (64%)]
# Train Epoch: 49 [79/107 (74%)]
# Train Epoch: 49 [89/107 (83%)]
# Train Epoch: 49 [99/107 (93%)]
# Data set: Average loss: 0.0000
# Train Epoch: 50 [9/107 (8%)]
# Train Epoch: 50 [19/107 (18%)]
# Train Epoch: 50 [29/107 (27%)]
# Train Epoch: 50 [39/107 (36%)]
# Train Epoch: 50 [49/107 (46%)]
# Train Epoch: 50 [59/107 (55%)]
# Train Epoch: 50 [69/107 (64%)]
# Train Epoch: 50 [79/107 (74%)]
# Train Epoch: 50 [89/107 (83%)]
# Train Epoch: 50 [99/107 (93%)]
# Data set: Average loss: 0.0000

# %%
plt.plot(range(train_epochs_start, train_epochs_end), avg_losses)
plt.xlabel('Epoch')
plt.ylabel('Average loss')
plt.savefig('ssl2_loss.png')
plt.show()

# %%
plot_change(model.cpu(), model_old)

# %%
model = model.cpu()
fig, axes = plt.subplots(3, 4)
for i in range(3):
    samples = dataset[i * 200] # so that the images are different
    image0, label0 = samples['img0'], samples['label0']
    image1, label1 = samples['img1'], samples['label1']
    image2, label2 = samples['img2'], samples['label2']
    image3, label3 = samples['img3'], samples['label3']
    gradcam(model, image0, detransformer, label0, axes[i][0])
    gradcam(model, image1, detransformer, label1, axes[i][1])
    gradcam(model, image2, detransformer, label2, axes[i][2])
    gradcam(model, image3, detransformer, label3, axes[i][3])

fig.savefig('ssl2_gradcam.png')
fig.show()

# %%
torch.save(model.state_dict(), 'ssl2.pt')

# %% [markdown]
# # Fine-tuning the model on the final task

# %%
os.mkdir('model_backup')
os.mkdir('model_result')

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)
np.random.seed(42)
torch.backends.cudnn.deterministic = True
rng = np.random.RandomState(42)

# %%
from sklearn.metrics import roc_auc_score
import torch.nn.functional as F

torch.cuda.empty_cache()


batchsize = 16
train_epochs_start = 0
train_epochs_end = 50
ssl2_epochs = 50

# %%
class FineTune(torch.nn.Module):
    def __init__(self, ssl_model, out_dim=2):
        super(FineTune, self).__init__()

        self.features = ssl_model.features
        self.relu = nn.ReLU(inplace=True)
        self.classifier = nn.Linear(
            ssl_model.classifier.in_features,
            out_features=out_dim,
            bias=True
        )

    def forward(self, x):
        out = self.features(x)
        out = self.relu(out)
        out = F.adaptive_avg_pool2d(out, (1, 1))
        out = torch.flatten(out, 1)
        out = self.classifier(out)
        return out

# %%
model = RotNet()
modelname = 'RotNet'

if train_epochs_start > 0:
    model = FineTune(model)
    modelname = 'FineTune'
    model.load_state_dict(
        torch.load('model_backup/{}_{}.pt'.format(
            modelname,
            train_epochs_start
        ))
    )
else:
    model.load_state_dict(
        torch.load('ssl2_backup/{}_{}.pt'.format(
            modelname,
            ssl2_epochs
        ))
    )
    model = FineTune(model)
    modelname = 'FineTune'

if device == 'cuda':
    model = model.cuda()

# %%
model_old = FineTune(RotNet())
model_old.load_state_dict(model.state_dict())
# Out:
# <All keys matched successfully>

# %%
normalize = transforms.Normalize(
    mean=[0.45271412, 0.45271412, 0.45271412],
    std=[0.33165374, 0.33165374, 0.33165374]
)
train_transformer = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    normalize
])

val_transformer = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    normalize
])

# %%
# This definition overrides the previous one
class CovidCTDataset(Dataset):
    def __init__(self, root_dir, txt_COVID, txt_NonCOVID, transform=None):
        """
            Args:
                txt_path (string): Path to the txt file with annotations.
                root_dir (string): Directory with all the images.
                transform (callable, optional): Optional transform to be applied on a sample.
            File structure:
                - root_dir
                    - CT_COVID
                        - img1.png
                        - img2.png
                        - ......
                    - CT_NonCOVID
                        - img1.png
                        - img2.png
                        - ......
        """
        self.root_dir = root_dir
        self.txt_path = [txt_COVID, txt_NonCOVID]
        self.classes = ['CT_COVID', 'CT_NonCOVID']
        self.num_cls = len(self.classes)
        self.img_list = []
        for c in range(self.num_cls):
            cls_list = [[os.path.join(self.root_dir, self.classes[c], item), c] for item in read_txt(self.txt_path[c])]
            self.img_list += cls_list
        self.transform = transform

    def __len__(self):
        return len(self.img_list)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_path = self.img_list[idx][0]
        image = Image.open(img_path).convert('RGB')

        if self.transform:
            image = self.transform(image)
        sample = {'img': image, 'label': int(self.img_list[idx][1])}
        return sample

# %%
trainset = CovidCTDataset(
    root_dir='Images',
    txt_COVID='Data-split/COVID/trainCT_COVID.txt',
    txt_NonCOVID='Data-split/NonCOVID/trainCT_NonCOVID.txt',
    transform=train_transformer
)
valset = CovidCTDataset(
    root_dir='Images',
    txt_COVID='Data-split/COVID/valCT_COVID.txt',
    txt_NonCOVID='Data-split/NonCOVID/valCT_NonCOVID.txt',
    transform=val_transformer
)
testset = CovidCTDataset(
    root_dir='Images',
    txt_COVID='Data-split/COVID/testCT_COVID.txt',
    txt_NonCOVID='Data-split/NonCOVID/testCT_NonCOVID.txt',
    transform=val_transformer
)
print("trainset length:", trainset.__len__())
print("valset length:", valset.__len__())
print("testset length:", testset.__len__())

train_loader = DataLoader(trainset, batch_size=batchsize, drop_last=False, shuffle=True)
val_loader = DataLoader(valset, batch_size=batchsize, drop_last=False, shuffle=False)
test_loader = DataLoader(testset, batch_size=batchsize, drop_last=False, shuffle=False)
# Out:
# trainset length: 425
# valset length: 118
# testset length: 203

# %%
def train(epoch):
        
    model.train()
        
    train_loss = 0
    train_correct = 0
        
    for batch_index, batch_samples in enumerate(train_loader):
                
        # move data to device
        data, target = batch_samples['img'].to(device), batch_samples['label'].to(device)

        output = model(data)
        loss = criteria(output, target.long())
        train_loss += loss.item()
                
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        pred = output.argmax(dim=1)
        train_correct += (pred == target).sum().item()
        
        # Display progress
        if (batch_index + 1) % bs == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}'.format(
                epoch,
                batch_index, len(train_loader),
                100.0 * batch_index / len(train_loader),
                train_loss / bs
            ))
            train_loss = 0
        
    avg_loss = train_loss / len(train_loader.dataset)
    accuracy = 100.0 * train_correct / len(train_loader.dataset)
    print('Train set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        avg_loss,
        train_correct, len(train_loader.dataset),
        accuracy
    ))
    f = open('model_result/train_{}.txt'.format(modelname), 'a+')
    f.write('Train set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        avg_loss,
        train_correct, len(train_loader.dataset),
        accuracy
    ))
    f.close()
    avg_losses.append(avg_loss)

# %%
 def predict(mode):
    '''
        mode:
            either 'val' or 'test'
    '''
    loader = val_loader if mode == 'val' else test_loader
        
    model.eval()

    predlist=[]
    scorelist=[]
    targetlist=[]
        
    # Don't update model
    with torch.no_grad():
        # Predict
        for batch_index, batch_samples in enumerate(loader):
            data, target = batch_samples['img'].to(device), batch_samples['label'].to(device)
            output = model(data)
                        
            score = F.softmax(output, dim=1)
            pred = output.argmax(dim=1)

            targetcpu=target.long().cpu().numpy()
            predlist=np.append(predlist, pred.cpu().numpy())
            scorelist=np.append(scorelist, score.cpu().numpy()[:,1]) # percentages for positive
            targetlist=np.append(targetlist, targetcpu)
                                  
    return targetlist, scorelist, predlist

# %%
bs = 10
votenum = 5
epochs, rs, ps, F1s, accs, AUCs = [], [], [], [], [], []
avg_losses = []

vote_pred = np.zeros(valset.__len__())
vote_score = np.zeros(valset.__len__())

criteria = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

for epoch in range(train_epochs_start + 1, train_epochs_end + 1):
    train(epoch)

    targetlist, scorelist, predlist = predict('val')
    vote_pred = vote_pred + predlist
    vote_score = vote_score + scorelist

    if epoch % votenum == 0:
        # checkpoint
        torch.save(model.state_dict(), "model_backup/{}_{}.pt".format(modelname, epoch))
                
        # major vote
        vote_pred[vote_pred <=  (votenum / 2)] = 0
        vote_pred[vote_pred >   (votenum / 2)] = 1
        vote_score = vote_score / votenum

        TP = ((vote_pred == 1) & (targetlist == 1)).sum()
        TN = ((vote_pred == 0) & (targetlist == 0)).sum()
        FN = ((vote_pred == 0) & (targetlist == 1)).sum()
        FP = ((vote_pred == 1) & (targetlist == 0)).sum()
                
        print('TP=',TP,'TN=',TN,'FN=',FN,'FP=',FP)
        print('TP+FP',TP + FP)
        p = TP / (TP + FP)
        r = TP / (TP + FN)
        F1 = 2 * r * p / (r + p)
        acc = (TP + TN) / (TP + TN + FP + FN)
        AUC = roc_auc_score(targetlist, vote_score)

        print('The epoch is {}, average recall: {:.4f}, average precision: {:.4f}, average F1: {:.4f}, average accuracy: {:.4f}, average AUC: {:.4f}\n\n'.format(
            epoch, r, p, F1, acc, AUC
        ))
        f = open('model_result/train_{}.txt'.format(modelname), 'a+')
        f.write('The epoch is {}, average recall: {:.4f}, average precision: {:.4f}, average F1: {:.4f}, average accuracy: {:.4f}, average AUC: {:.4f}\n\n'.format(
            epoch, r, p, F1, acc, AUC
        ))
        f.close()

        epochs.append(epoch)
        rs.append(r)
        ps.append(p)
        F1s.append(F1)
        accs.append(acc)
        AUCs.append(AUC)
                
        vote_pred = np.zeros(valset.__len__())
        vote_score = np.zeros(valset.__len__())
# Out:
# Train Epoch: 1 [9/27 (33%)]	Train Loss: 0.658002
# Train Epoch: 1 [19/27 (70%)]	Train Loss: 0.543687
# Train set: Average loss: 0.0106, Accuracy: 282/425 (66%)
#
# Train Epoch: 2 [9/27 (33%)]	Train Loss: 0.580205
# Train Epoch: 2 [19/27 (70%)]	Train Loss: 0.528106
# Train set: Average loss: 0.0086, Accuracy: 305/425 (72%)
#
# Train Epoch: 3 [9/27 (33%)]	Train Loss: 0.451190
# Train Epoch: 3 [19/27 (70%)]	Train Loss: 0.437797
# Train set: Average loss: 0.0105, Accuracy: 328/425 (77%)
#
# Train Epoch: 4 [9/27 (33%)]	Train Loss: 0.567729
# Train Epoch: 4 [19/27 (70%)]	Train Loss: 0.573252
# Train set: Average loss: 0.0077, Accuracy: 308/425 (72%)
#
# Train Epoch: 5 [9/27 (33%)]	Train Loss: 0.711451
# Train Epoch: 5 [19/27 (70%)]	Train Loss: 0.653061
# Train set: Average loss: 0.0090, Accuracy: 279/425 (66%)
#
# TP= 15 TN= 53 FN= 43 FP= 7
# TP+FP 22
# The epoch is 5, average recall: 0.2586, average precision: 0.6818, average F1: 0.3750, average accuracy: 0.5763, average AUC: 0.7353
#
#
# Train Epoch: 6 [9/27 (33%)]	Train Loss: 0.500882
# Train Epoch: 6 [19/27 (70%)]	Train Loss: 0.545057
# Train set: Average loss: 0.0089, Accuracy: 314/425 (74%)
#
# Train Epoch: 7 [9/27 (33%)]	Train Loss: 0.393430
# Train Epoch: 7 [19/27 (70%)]	Train Loss: 0.483783
# Train set: Average loss: 0.0093, Accuracy: 333/425 (78%)
#
# Train Epoch: 8 [9/27 (33%)]	Train Loss: 0.461000
# Train Epoch: 8 [19/27 (70%)]	Train Loss: 0.331376
# Train set: Average loss: 0.0069, Accuracy: 354/425 (83%)
#
# Train Epoch: 9 [9/27 (33%)]	Train Loss: 0.344835
# Train Epoch: 9 [19/27 (70%)]	Train Loss: 0.359791
# Train set: Average loss: 0.0074, Accuracy: 357/425 (84%)
#
# Train Epoch: 10 [9/27 (33%)]	Train Loss: 0.309919
# Train Epoch: 10 [19/27 (70%)]	Train Loss: 0.416161
# Train set: Average loss: 0.0041, Accuracy: 363/425 (85%)
#
# TP= 36 TN= 38 FN= 22 FP= 22
# TP+FP 58
# The epoch is 10, average recall: 0.6207, average precision: 0.6207, average F1: 0.6207, average accuracy: 0.6271, average AUC: 0.7310
#
#
# Train Epoch: 11 [9/27 (33%)]	Train Loss: 0.297115
# Train Epoch: 11 [19/27 (70%)]	Train Loss: 0.417641
# Train set: Average loss: 0.0102, Accuracy: 345/425 (81%)
#
# Train Epoch: 12 [9/27 (33%)]	Train Loss: 0.540365
# Train Epoch: 12 [19/27 (70%)]	Train Loss: 0.422648
# Train set: Average loss: 0.0066, Accuracy: 335/425 (79%)
#
# Train Epoch: 13 [9/27 (33%)]	Train Loss: 0.308783
# Train Epoch: 13 [19/27 (70%)]	Train Loss: 0.294721
# Train set: Average loss: 0.0065, Accuracy: 369/425 (87%)
#
# Train Epoch: 14 [9/27 (33%)]	Train Loss: 0.281435
# Train Epoch: 14 [19/27 (70%)]	Train Loss: 0.283967
# Train set: Average loss: 0.0083, Accuracy: 362/425 (85%)
#
# Train Epoch: 15 [9/27 (33%)]	Train Loss: 0.293279
# Train Epoch: 15 [19/27 (70%)]	Train Loss: 0.270378
# Train set: Average loss: 0.0040, Accuracy: 377/425 (89%)
#
# TP= 35 TN= 50 FN= 23 FP= 10
# TP+FP 45
# The epoch is 15, average recall: 0.6034, average precision: 0.7778, average F1: 0.6796, average accuracy: 0.7203, average AUC: 0.8181
#
#
# Train Epoch: 16 [9/27 (33%)]	Train Loss: 0.187132
# Train Epoch: 16 [19/27 (70%)]	Train Loss: 0.267208
# Train set: Average loss: 0.0024, Accuracy: 388/425 (91%)
#
# Train Epoch: 17 [9/27 (33%)]	Train Loss: 0.342625
# Train Epoch: 17 [19/27 (70%)]	Train Loss: 0.282661
# Train set: Average loss: 0.0036, Accuracy: 373/425 (88%)
#
# Train Epoch: 18 [9/27 (33%)]	Train Loss: 0.268884
# Train Epoch: 18 [19/27 (70%)]	Train Loss: 0.152298
# Train set: Average loss: 0.0018, Accuracy: 395/425 (93%)
#
# Train Epoch: 19 [9/27 (33%)]	Train Loss: 0.079736
# Train Epoch: 19 [19/27 (70%)]	Train Loss: 0.128582
# Train set: Average loss: 0.0025, Accuracy: 408/425 (96%)
#
# Train Epoch: 20 [9/27 (33%)]	Train Loss: 0.181724
# Train Epoch: 20 [19/27 (70%)]	Train Loss: 0.289002
# Train set: Average loss: 0.0032, Accuracy: 390/425 (92%)
#
# TP= 39 TN= 47 FN= 19 FP= 13
# TP+FP 52
# The epoch is 20, average recall: 0.6724, average precision: 0.7500, average F1: 0.7091, average accuracy: 0.7288, average AUC: 0.7664
#
#
# Train Epoch: 21 [9/27 (33%)]	Train Loss: 0.146853
# Train Epoch: 21 [19/27 (70%)]	Train Loss: 0.175144
# Train set: Average loss: 0.0044, Accuracy: 393/425 (92%)
#
# Train Epoch: 22 [9/27 (33%)]	Train Loss: 0.159670
# Train Epoch: 22 [19/27 (70%)]	Train Loss: 0.222929
# Train set: Average loss: 0.0032, Accuracy: 389/425 (92%)
#
# Train Epoch: 23 [9/27 (33%)]	Train Loss: 0.327168
# Train Epoch: 23 [19/27 (70%)]	Train Loss: 0.191242
# Train set: Average loss: 0.0047, Accuracy: 380/425 (89%)
#
# Train Epoch: 24 [9/27 (33%)]	Train Loss: 0.158302
# Train Epoch: 24 [19/27 (70%)]	Train Loss: 0.162467
# Train set: Average loss: 0.0024, Accuracy: 401/425 (94%)
#
# Train Epoch: 25 [9/27 (33%)]	Train Loss: 0.113731
# Train Epoch: 25 [19/27 (70%)]	Train Loss: 0.064655
# Train set: Average loss: 0.0015, Accuracy: 410/425 (96%)
#
# TP= 38 TN= 45 FN= 20 FP= 15
# TP+FP 53
# The epoch is 25, average recall: 0.6552, average precision: 0.7170, average F1: 0.6847, average accuracy: 0.7034, average AUC: 0.7836
#
#
# Train Epoch: 26 [9/27 (33%)]	Train Loss: 0.085802
# Train Epoch: 26 [19/27 (70%)]	Train Loss: 0.098200
# Train set: Average loss: 0.0023, Accuracy: 405/425 (95%)
#
# Train Epoch: 27 [9/27 (33%)]	Train Loss: 0.159628
# Train Epoch: 27 [19/27 (70%)]	Train Loss: 0.159460
# Train set: Average loss: 0.0036, Accuracy: 400/425 (94%)
#
# Train Epoch: 28 [9/27 (33%)]	Train Loss: 0.091116
# Train Epoch: 28 [19/27 (70%)]	Train Loss: 0.120393
# Train set: Average loss: 0.0013, Accuracy: 412/425 (97%)
#
# Train Epoch: 29 [9/27 (33%)]	Train Loss: 0.103038
# Train Epoch: 29 [19/27 (70%)]	Train Loss: 0.081372
# Train set: Average loss: 0.0044, Accuracy: 403/425 (95%)
#
# Train Epoch: 30 [9/27 (33%)]	Train Loss: 0.159872
# Train Epoch: 30 [19/27 (70%)]	Train Loss: 0.118303
# Train set: Average loss: 0.0020, Accuracy: 399/425 (94%)
#
# TP= 48 TN= 29 FN= 10 FP= 31
# TP+FP 79
# The epoch is 30, average recall: 0.8276, average precision: 0.6076, average F1: 0.7007, average accuracy: 0.6525, average AUC: 0.7724
#
#
# Train Epoch: 31 [9/27 (33%)]	Train Loss: 0.118479
# Train Epoch: 31 [19/27 (70%)]	Train Loss: 0.152685
# Train set: Average loss: 0.0027, Accuracy: 401/425 (94%)
#
# Train Epoch: 32 [9/27 (33%)]	Train Loss: 0.106146
# Train Epoch: 32 [19/27 (70%)]	Train Loss: 0.137898
# Train set: Average loss: 0.0016, Accuracy: 404/425 (95%)
#
# Train Epoch: 33 [9/27 (33%)]	Train Loss: 0.066309
# Train Epoch: 33 [19/27 (70%)]	Train Loss: 0.107006
# Train set: Average loss: 0.0012, Accuracy: 410/425 (96%)
#
# Train Epoch: 34 [9/27 (33%)]	Train Loss: 0.126533
# Train Epoch: 34 [19/27 (70%)]	Train Loss: 0.151620
# Train set: Average loss: 0.0026, Accuracy: 399/425 (94%)
#
# Train Epoch: 35 [9/27 (33%)]	Train Loss: 0.110317
# Train Epoch: 35 [19/27 (70%)]	Train Loss: 0.129401
# Train set: Average loss: 0.0036, Accuracy: 399/425 (94%)
#
# TP= 39 TN= 47 FN= 19 FP= 13
# TP+FP 52
# The epoch is 35, average recall: 0.6724, average precision: 0.7500, average F1: 0.7091, average accuracy: 0.7288, average AUC: 0.7983
#
#
# Train Epoch: 36 [9/27 (33%)]	Train Loss: 0.074243
# Train Epoch: 36 [19/27 (70%)]	Train Loss: 0.065725
# Train set: Average loss: 0.0012, Accuracy: 415/425 (98%)
#
# Train Epoch: 37 [9/27 (33%)]	Train Loss: 0.027762
# Train Epoch: 37 [19/27 (70%)]	Train Loss: 0.105215
# Train set: Average loss: 0.0003, Accuracy: 419/425 (99%)
#
# Train Epoch: 38 [9/27 (33%)]	Train Loss: 0.045521
# Train Epoch: 38 [19/27 (70%)]	Train Loss: 0.061169
# Train set: Average loss: 0.0005, Accuracy: 419/425 (99%)
#
# Train Epoch: 39 [9/27 (33%)]	Train Loss: 0.019166
# Train Epoch: 39 [19/27 (70%)]	Train Loss: 0.091000
# Train set: Average loss: 0.0010, Accuracy: 416/425 (98%)
#
# Train Epoch: 40 [9/27 (33%)]	Train Loss: 0.031669
# Train Epoch: 40 [19/27 (70%)]	Train Loss: 0.030675
# Train set: Average loss: 0.0002, Accuracy: 424/425 (100%)
#
# TP= 43 TN= 45 FN= 15 FP= 15
# TP+FP 58
# The epoch is 40, average recall: 0.7414, average precision: 0.7414, average F1: 0.7414, average accuracy: 0.7458, average AUC: 0.8244
#
#
# Train Epoch: 41 [9/27 (33%)]	Train Loss: 0.039050
# Train Epoch: 41 [19/27 (70%)]	Train Loss: 0.084866
# Train set: Average loss: 0.0011, Accuracy: 415/425 (98%)
#
# Train Epoch: 42 [9/27 (33%)]	Train Loss: 0.114278
# Train Epoch: 42 [19/27 (70%)]	Train Loss: 0.095616
# Train set: Average loss: 0.0019, Accuracy: 408/425 (96%)
#
# Train Epoch: 43 [9/27 (33%)]	Train Loss: 0.046553
# Train Epoch: 43 [19/27 (70%)]	Train Loss: 0.055682
# Train set: Average loss: 0.0022, Accuracy: 413/425 (97%)
#
# Train Epoch: 44 [9/27 (33%)]	Train Loss: 0.099547
# Train Epoch: 44 [19/27 (70%)]	Train Loss: 0.054861
# Train set: Average loss: 0.0059, Accuracy: 407/425 (96%)
#
# Train Epoch: 45 [9/27 (33%)]	Train Loss: 0.134202
# Train Epoch: 45 [19/27 (70%)]	Train Loss: 0.382984
# Train set: Average loss: 0.0087, Accuracy: 377/425 (89%)
#
# TP= 39 TN= 44 FN= 19 FP= 16
# TP+FP 55
# The epoch is 45, average recall: 0.6724, average precision: 0.7091, average F1: 0.6903, average accuracy: 0.7034, average AUC: 0.7767
#
#
# Train Epoch: 46 [9/27 (33%)]	Train Loss: 0.352195
# Train Epoch: 46 [19/27 (70%)]	Train Loss: 0.172945
# Train set: Average loss: 0.0017, Accuracy: 387/425 (91%)
#
# Train Epoch: 47 [9/27 (33%)]	Train Loss: 0.047646
# Train Epoch: 47 [19/27 (70%)]	Train Loss: 0.038033
# Train set: Average loss: 0.0023, Accuracy: 415/425 (98%)
#
# Train Epoch: 48 [9/27 (33%)]	Train Loss: 0.141210
# Train Epoch: 48 [19/27 (70%)]	Train Loss: 0.089021
# Train set: Average loss: 0.0011, Accuracy: 411/425 (97%)
#
# Train Epoch: 49 [9/27 (33%)]	Train Loss: 0.046254
# Train Epoch: 49 [19/27 (70%)]	Train Loss: 0.025982
# Train set: Average loss: 0.0012, Accuracy: 417/425 (98%)
#
# Train Epoch: 50 [9/27 (33%)]	Train Loss: 0.067923
# Train Epoch: 50 [19/27 (70%)]	Train Loss: 0.139264
# Train set: Average loss: 0.0010, Accuracy: 413/425 (97%)
#
# TP= 49 TN= 38 FN= 9 FP= 22
# TP+FP 71
# The epoch is 50, average recall: 0.8448, average precision: 0.6901, average F1: 0.7597, average accuracy: 0.7373, average AUC: 0.7937

# %%
plt.plot(epochs, rs, label='Recall')
plt.plot(epochs, ps, label='Precision')
plt.plot(epochs, F1s, label='F1')
plt.plot(epochs, accs, label='Accuracy')
plt.plot(epochs, AUCs, label='AUC')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Training result')
plt.xticks(epochs)
plt.savefig('validation_performance.png')
plt.show()

# %%
plt.plot(range(train_epochs_start, train_epochs_end), avg_losses)
plt.xlabel('Epoch')
plt.ylabel('Average loss')
plt.title('Training loss during fine-tuning')
plt.savefig('fine-tuning_loss.png')
plt.show()

# %%
plot_change(model.cpu(), model_old)
model = model.cuda()

# %%
bs = 10

        
targetlist, scorelist, predlist = predict('test')
        
TP = ((predlist == 1) & (targetlist == 1)).sum()
TN = ((predlist == 0) & (targetlist == 0)).sum()
FN = ((predlist == 0) & (targetlist == 1)).sum()
FP = ((predlist == 1) & (targetlist == 0)).sum()

print('TP=',TP,'TN=',TN,'FN=',FN,'FP=',FP)
print('TP+FP',TP+FP)
p = TP / (TP + FP)
r = TP / (TP + FN)
F1 = 2 * r * p / (r + p)
acc = (TP + TN) / (TP + TN + FP + FN)
AUC = roc_auc_score(targetlist, scorelist)

print('Testing, average recall: {:.4f}, average precision: {:.4f}, average F1: {:.4f}, average accuracy: {:.4f}, average AUC: {:.4f}\n'.format(
    r, p, F1, acc, AUC
))
f = open('model_result/test_{}.txt'.format(modelname), 'a+')
f.write('Testing, average recall: {:.4f}, average precision: {:.4f}, average F1: {:.4f}, average accuracy: {:.4f}, average AUC: {:.4f}\n'.format(
    r, p, F1, acc, AUC
))
f.close()
# Out:
# TP= 98 TN= 49 FN= 7 FP= 49
# TP+FP 147
# Testing, average recall: 0.9333, average precision: 0.6667, average F1: 0.7778, average accuracy: 0.7241, average AUC: 0.7776

# %%
model = model.cpu()
fig, axes = plt.subplots(2, 4)
negatives = 0
positives = 0
for i in range(len(testset)):
    if negatives == 4 and positives == 4:
        break
    image, label = testset[i]['img'], testset[i]['label']
    if label == 0 and negatives < 4:
        gradcam(model, image, detransformer, label, axes[0][negatives])
        negatives = negatives + 1
    elif label == 1 and positives < 4:
        gradcam(model, image, detransformer, label, axes[1][positives])
        positives = positives + 1

fig.savefig('fine-tuning_gradcam.png')
fig.show()

# %%
torch.save(model.state_dict(), 'fine-tune.pt')
